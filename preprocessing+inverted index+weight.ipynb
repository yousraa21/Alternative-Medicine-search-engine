# %%
import re
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

class TextPreprocessor:
    def preprocess_text(self, tokens, tokenize=True, normalize=True, remove_stopwords=True, stem=True):
        if tokenize:
            tokens = word_tokenize(tokens)
        else:
            tokens = re.findall(r'\b\w+\b', tokens)

        if normalize:
            tokens = [word.lower() for word in tokens if word.isalpha()]

        if remove_stopwords:
            stop_words = set(stopwords.words('english'))
            tokens = [word for word in tokens if word not in stop_words]

        if stem:
            stemmer = PorterStemmer()
            tokens = [stemmer.stem(word) for word in tokens]

        return tokens

# Charger les données depuis 'DATA.txt'
with open('C:\\Users\\poste\\Desktop\\build\\DATA-OF-ALTERNATIVE-MEDICINE-1.txt', 'r', encoding='utf-8') as file:
    data = file.read()

# Initialiser le préprocesseur de texte
preprocessor = TextPreprocessor()

# Diviser les documents à partir du mot-clé "D1:"
documents = re.split(r'(D[0-9]+:)', data)[1:]

# Liste pour stocker les résultats traités
processed_documents = []

# Traitement de chaque document individuellement
for i in range(0, len(documents), 2):
    document_name = documents[i]
    document_content = documents[i + 1]
    
    processed_document = preprocessor.preprocess_text(document_content)
    processed_documents.append((document_name, processed_document))

# Enregistrement des résultats dans un nouveau fichier texte
output_file_path = 'C:\\Users\\poste\\Desktop\\build\\processed_documents.txt'
with open(output_file_path, 'w', encoding='utf-8') as output_file:
    for document_name, processed_document in processed_documents:
        output_file.write(f"{document_name}\n")
        output_file.write(" ".join(processed_document))
        output_file.write("\n" + "="*50 + "\n")

print(f"Les résultats ont été enregistrés dans le fichier : {output_file_path}")
# Out:
# Les résultats ont été enregistrés dans le fichier : C:\Users\poste\Desktop\build\processed_documents.txt

# %%
from collections import defaultdict
import re
import json

# Function to preprocess a document (tokenization, lowercasing, etc.) and store word positions
def preprocess_with_positions(text):
    text = text.lower()  # Convert text to lowercase
    words = re.findall(r'\b\w+\b', text)  # Tokenize the text into words
    word_positions = defaultdict(list)
    for idx, word in enumerate(words):
        word_positions[word].append(idx)
    return word_positions

# Function to create inverted index from documents with word positions
def create_inverted_index_with_positions(documents):
    inverted_index = defaultdict(list)
    for doc_id, doc_text in documents.items():
        word_positions = preprocess_with_positions(doc_text)
        for word, positions in word_positions.items():
            inverted_index[word].append([doc_id[1:], positions])  # Exclude the first character 'D'
    return inverted_index

# Read the contents of the text file with preprocessed documents
file_path = 'C:\\Users\\poste\\Desktop\\build\\processed_documents.txt'  # Replace with your file path
documents = {}

# Read and parse the documents
with open(file_path, 'r') as file:
    lines = file.readlines()
    doc_id = None
    doc_text = ""
    for line in lines:
        line = line.strip()
        if line.startswith("D"):
            if doc_id:
                documents[doc_id] = doc_text
            doc_id = line
            doc_text = ""
        elif line.startswith("="):
            continue
        else:
            doc_text += line

    # Add the last document
    if doc_id:
        documents[doc_id] = doc_text

# Create inverted index with word positions
inverted_index_positions = create_inverted_index_with_positions(documents)

# Save the formatted inverted index to a JSON file
output_file_path = 'C:\\Users\\poste\\Desktop\\build\\inverted-index.json'
with open(output_file_path, 'w') as output_file:
    json.dump(inverted_index_positions, output_file, indent=None)

print(f"Inverted index saved to {output_file_path}")
# Out:
# Inverted index saved to C:\Users\poste\Desktop\build\inverted-index.json

# %%
import math

# Function to calculate TF-IDF for each word across all documents
def calculate_tfidf_for_words(inverted_index, total_docs, documents):
    tfidf = {}
    for term, doc_positions in inverted_index.items():
        doc_freq = len(doc_positions)
        idf = math.log(total_docs / doc_freq) if doc_freq > 0 else 0

        for doc_info in doc_positions:
            doc_id, positions = doc_info[0], doc_info[1]

            # Remove the colon from the document ID
            doc_id = doc_id[:-1]

            # Check if the document ID exists in the documents list
            if doc_id in documents:
                tf = len(positions) / len(documents[doc_id])
                tfidf.setdefault(term, {})[doc_id] = tf * idf
            
    return tfidf

# Example usage:
# Use the inverted_index_positions created previously

# Assuming documents is a dictionary
# Calculate TF-IDF for each word
total_documents = len(documents)
tfidf_scores_for_words = calculate_tfidf_for_words(inverted_index_positions, total_documents, documents)

# Save the TF-IDF scores to a text file in the desired format
tfidf_output_file_path = 'C:\\Users\\poste\\Desktop\\build\\tfidf-result.txt'
with open(tfidf_output_file_path, 'w') as tfidf_output_file:
    for term, doc_scores in tfidf_scores_for_words.items():
        tfidf_output_file.write(f"{term}:\n")
        for doc_id, score in doc_scores.items():
            tfidf_output_file.write(f"{doc_id}: {score}\n")

print(f"TF-IDF scores saved to {tfidf_output_file_path}")
# Out:
# TF-IDF scores saved to C:\Users\poste\Desktop\build\tfidf-result.txt

# %%
import numpy as np

# Function to calculate weights for each word using TF-IDF scores
def calculate_weights(tfidf_scores_for_words):
    word_weights = {}
    for word, doc_scores in tfidf_scores_for_words.items():
        scores_array = np.array(list(doc_scores.values()))
        normalized_scores = scores_array / np.linalg.norm(scores_array)
        word_weights[word] = normalized_scores
    return word_weights

# Example usage:
# Use the tfidf_scores_for_words dictionary calculated previously

# Calculate weights for each word
word_weights = calculate_weights(tfidf_scores_for_words)

# Display word weights
for word, weights in word_weights.items():
    print(f'{word}: {weights}')

# Save the word weights to a text file
weights_output_file_path = 'C:\\Users\\poste\\Desktop\\build\\weight-result.txt'
with open(weights_output_file_path, 'w') as weights_output_file:
    for word, weights in word_weights.items():
        weights_output_file.write(f'{word}: {weights}\n')

print(f"Word weights saved to {weights_output_file_path}")
# Out:
# scale: [1.]
# human: [0.59071647 0.33712227 0.7330775 ]
# immunodefici: [0.86851535 0.49566227]
# viru: [0.59071647 0.33712227 0.7330775 ]
# hiv: [0.46599092 0.47231659 0.26594131 0.22138275 0.15997236 0.57829344
#  0.28287796]
# epidem: [0.90324966 0.42911543]
# exceed: [0.8830479  0.46928287]
# expect: [0.86851535 0.49566227]
# sinc: [1.]
# identif: [1.]
# year: [0.86851535 0.49566227]
# ago: [1.]
# global: [0.90324966 0.42911543]
# estim: [1.]
# million: [0.70232381 0.71185762]
# peopl: [0.34566047 0.35035269 0.19726865 0.11866352 0.58880567 0.18369619
#  0.54719396 0.15785514]
# current: [0.70232381 0.71185762]
# live: [0.32659268 0.33102607 0.11211764 0.40530062 0.55632518 0.1735629
#  0.51700891]
# alreadi: [0.70232381 0.71185762]
# die: [1.]
# worst: [1.]
# center: [1.]
# africa: [0.47671512 0.48318636 0.25334327 0.54621067 0.42041018]
# spread: [0.59071647 0.33712227 0.7330775 ]
# greater: [1.]
# predict: [1.]
# impact: [0.87013226 0.49281827]
# social: [1.]
# capit: [1.]
# popul: [0.90324966 0.42911543]
# structur: [1.]
# econom: [1.]
# growth: [0.69413729 0.32977042 0.63986318]
# respond: [1.]
# aid: [0.56090971 0.32011153 0.19255751 0.69608739 0.24757394]
# commensur: [1.]
# imper: [1.]
# tool: [0.27336662 0.56961976 0.77511549]
# effect: [0.66632202 0.31655595 0.22874503 0.37174628 0.28268207 0.30460435
#  0.30429385]
# respons: [0.260275   0.23992428 0.11041969 0.0674787  0.13848361 0.54234045
#  0.73799492]
# known: [0.59799233 0.31779426 0.27336792 0.34792281 0.25984536 0.52736331]
# noth: [1.]
# less: [1.]
# sustain: [1.]
# mobil: [0.90324966 0.42911543]
# necessari: [0.406823   0.22696974 0.17259157 0.18597623 0.8477056 ]
# combat: [0.89821771 0.18981204 0.39645471]
# one: [0.86851535 0.49566227]
# seriou: [0.80093247 0.20764916 0.42614934 0.36576733]
# crise: [1.]
# face: [1.]
# develop: [0.64534468 0.36829862 0.30659005 0.59488563]
# refer: [0.61476522 0.62311045 0.3508469  0.29206237 0.15938357]
# articl: [0.35481709 0.35963362 0.16856634 0.60440326 0.18856235 0.56168925]
# publish: [0.90324966 0.42911543]
# avril: [1.]
# two: [0.69897227 0.32762009 0.63569083]
# third: [1.]
# world: [0.36917962 0.33575595 0.20629253 0.21191869 0.15827099 0.1607659
#  0.09443136 0.75896461 0.16633781]
# resid: [1.]
# opportunist: [0.37876507 0.21326645 0.12828671 0.63655575 0.19859331 0.59156947]
# infect: [0.367176   0.20674113 0.17210158 0.12436153 0.61707905 0.19251695
#  0.57346922 0.07655273 0.15741202]
# oi: [0.85790294 0.51381179]
# associ: [0.34875046 0.11812085 0.31717635 0.194877   0.55448815 0.575178
#  0.19196476 0.07271118 0.14951281 0.15186966]
# singl: [0.66257388 0.74899656]
# import: [0.77257493 0.3621189  0.26166906 0.19761465 0.40555596]
# caus: [0.49160778 0.16650624 0.81078597 0.27059855]
# mortal: [1.]
# morbid: [1.]
# among: [0.38076551 0.22804655 0.63991769 0.19964217 0.59469383]
# patient: [0.85790294 0.51381179]
# poor: [1.]
# countri: [0.90547047 0.42440928]
# widespread: [0.85790294 0.51381179]
# use: [0.2570312  0.08705578 0.15394009 0.43196878 0.13476606 0.40144095
#  0.10758313 0.11592631 0.05358858 0.14754258 0.11019184 0.11326798
#  0.11192886 0.290557   0.22363738 0.06574525 0.13492611 0.52840832
#  0.11580814]
# medicin: [0.24932256 0.14038289 0.08444488 0.30526474 0.14932327 0.41901358
#  0.13072428 0.38940131 0.13931804 0.13723608 0.1043566  0.11244956
#  0.0519814  0.14311763 0.10688707 0.10987096 0.10857199 0.21693026
#  0.06377348 0.13087954 0.5125608 ]
# plant: [0.35436626 0.1200229  0.21223562 0.5955509  0.18580058 0.55346249
#  0.1561614  0.30832655]
# speci: [0.78239462 0.46858865 0.41022352]
# manag: [0.55071771 0.25813068 0.18652661 0.30313478 0.23050874 0.11481945
#  0.31612627 0.23609818 0.24268916 0.23981993 0.14086645 0.28909409
#  0.24813173]
# uganda: [0.39107011 0.6572357  0.20504506 0.61078795]
# even: [0.61016455 0.34355762 0.28599441 0.36543731 0.3199202  0.34095162
#  0.27519667]
# antiretrovir: [0.86567551 0.40575671 0.29320197]
# drug: [0.83573096 0.47056444 0.28305983]
# arv: [0.85790294 0.51381179]
# howev: [0.71914169 0.24357136 0.37705887 0.18394712 0.37750668 0.32401695]
# much: [1.]
# inform: [0.22354595 0.20330722 0.12491442 0.35542197 0.36868399 0.12304771
#  0.05718016 0.45956888 0.10072101 0.62536271]
# remain: [0.90547047 0.42440928]
# undocu: [1.]
# unverifi: [1.]
# site: [1.]
# nation: [1.]
# librari: [1.]
# indigen: [0.39107011 0.6572357  0.20504506 0.61078795]
# tradit: [0.33203282 0.11245863 0.55801714 0.17409076 0.5185813  0.13897586
#  0.14975358 0.06922571 0.19059546 0.14234579 0.14631955 0.14458966
#  0.2888947  0.08492969 0.17429751]
# knowledg: [0.26185356 0.12273518 0.44007328 0.13729451 0.40897269 0.73252704]
# herbalist: [0.37228753 0.12609279 0.22296895 0.62566953 0.19519702 0.58145261
#  0.16773811]
# treat: [0.34869349 0.20883811 0.5860172  0.18282624 0.54460256 0.14594936
#  0.20015912 0.3033908  0.08919128]
# attack: [1.]
# cell: [0.5263919  0.85024206]
# help: [0.2826659  0.17003274 0.61466131 0.26321795 0.28052178 0.27632968
#  0.21012569 0.22642115 0.10466638 0.22122904 0.21861353 0.12841015
#  0.26353056]
# bodi: [0.23903039 0.51977522 0.38608818 0.23721726 0.67495991 0.1085873 ]
# fight: [0.37911745 0.22805149 0.82439667 0.35303345]
# make: [0.23965014 0.19949667 0.37032551 0.87500166]
# person: [1.]
# vulner: [1.]
# diseas: [0.23908466 0.19902594 0.51989324 0.23727112 0.70030395 0.23372535
#  0.17772865]
# contact: [0.41781008 0.90853439]
# certain: [0.7067239  0.42511744 0.5655232 ]
# bodili: [1.]
# fluid: [0.41781008 0.90853439]
# share: [0.41781008 0.90853439]
# inject: [0.68495928 0.72858135]
# equip: [1.]
# late: [1.]
# stage: [0.856913   0.51546107]
# occur: [0.23410706 0.19488234 0.66105771 0.68572404]
# immun: [0.38541465 0.23183946 0.83809002 0.308725  ]
# system: [0.38541465 0.23183946 0.83809002 0.308725  ]
# badli: [1.]
# damag: [1.]
# take: [0.41798504 0.34795149 0.83917713]
# prescrib: [0.856913   0.51546107]
# stop: [0.41781008 0.90853439]
# progress: [0.856913   0.51546107]
# consid: [0.62547957 0.37624633 0.46496351 0.5010219 ]
# number: [1.]
# fall: [1.]
# per: [0.67508504 0.50183879 0.5407569 ]
# cubic: [1.]
# millimet: [1.]
# blood: [0.36676963 0.79754615 0.35854815 0.13580857 0.287053  ]
# someon: [1.]
# healthi: [1.]
# count: [1.]
# regardless: [1.]
# without: [1.]
# typic: [0.48478579 0.45143161 0.74912765]
# surviv: [1.]
# danger: [0.68495928 0.72858135]
# ill: [1.]
# life: [0.60679773 0.27565753 0.56571997 0.48556189]
# treatment: [0.1787827  0.14882759 0.10754361 0.3887657  0.19016859 0.28877452
#  0.17742657 0.50483603 0.52367319 0.17477511 0.13290191 0.08121783
#  0.16667983 0.14306261]
# still: [0.69761171 0.58072661 0.41963616]
# lifesav: [1.]
# start: [0.60679773 0.27565753 0.56571997 0.48556189]
# soon: [1.]
# get: [0.36110087 0.78521935 0.3583618  0.35300646]
# experi: [0.78079115 0.62479211]
# test: [0.71507591 0.69904681]
# mani: [0.32030879 0.19267617 0.69651635 0.31787914 0.31312877 0.14551065
#  0.29862518 0.25631234]
# herb: [0.13477943 0.08107422 0.29307993 0.14336295 0.40228843 0.12550635
#  0.13375709 0.13175823 0.10019115 0.10796108 0.04990654 0.13740501
#  0.10262062 0.1054854  0.10423828 0.27059298 0.20827137 0.06122793
#  0.10785103 0.669632  ]
# altern: [0.15177681 0.09129869 0.33004098 0.16144281 0.45302203 0.14133427
#  0.42100634 0.15062553 0.14837459 0.11282651 0.12157632 0.05620037
#  0.1547335  0.06894953 0.14150213 0.55416183]
# reduc: [0.3455598  0.20786547 0.75142505 0.34293862 0.33781375 0.12795493
#  0.15698174]
# symptom: [0.28620991 0.17216458 0.6223678  0.30443737 0.28403891 0.27979424
#  0.10597867 0.21791928 0.22400277 0.13002013 0.26683465 0.22902628]
# rid: [0.36110087 0.78521935 0.3583618  0.35300646]
# continu: [0.36110087 0.78521935 0.3583618  0.35300646]
# http: [0.21270492 0.34356659 0.21109148 0.6006236  0.62303493 0.20793694]
# asia: [0.48286618 0.46463552 0.5913543  0.44861361]
# ie: [1.]
# show: [1.]
# great: [1.]
# divers: [0.21135861 0.20337874 0.11534211 0.92702869 0.20317143]
# sever: [0.55765361 0.6548784  0.51005563]
# time: [0.35751863 0.93390601]
# far: [1.]
# includ: [0.21818762 0.26011495 0.76772734 0.19483989 0.20994993 0.09705232
#  0.19956443 0.40502151]
# china: [0.72856242 0.68497942]
# indonesia: [1.]
# vietnam: [1.]
# grow: [0.28073721 0.27013795 0.34381193 0.6770721  0.52113226]
# factor: [1.]
# affect: [1.]
# rate: [0.40205973 0.78012824 0.47932026]
# magnitud: [1.]
# preval: [1.]
# size: [0.35206186 0.39382483 0.84909037]
# sex: [1.]
# worker: [1.]
# frequenc: [1.]
# commerci: [1.]
# view: [1.]
# present: [1.]
# state: [1.]
# low: [0.64265842 0.76615283]
# might: [0.58709396 0.42423724 0.68945156]
# small: [0.31119296 0.29944383 0.28463138 0.29257723 0.28911818 0.75052419]
# percentag: [1.]
# becom: [0.28277203 0.95918714]
# establish: [0.74588753 0.66607191]
# need: [0.55524525 0.40122319 0.4958298  0.53373727]
# care: [0.2098252  0.1145053  0.23499426 0.92030309 0.20169741]
# unavoid: [1.]
# thailand: [1.]
# cambodia: [1.]
# see: [1.]
# burgeon: [1.]
# manifest: [0.64265842 0.76615283]
# region: [0.63247708 0.77457907]
# discuss: [1.]
# aim: [0.87779849 0.47903008]
# identifi: [1.]
# key: [0.57679076 0.25656306 0.54228683 0.5544482 ]
# issu: [0.43675953 0.39002295 0.19427558 0.53488862 0.41063234 0.40577758]
# medic: [0.11193746 0.08088661 0.1430312  0.12521593 0.13344757 0.13145333
#  0.09995931 0.10771125 0.04979105 0.13708705 0.10238315 0.1052413
#  0.10399707 0.26996682 0.20778942 0.06108624 0.12536464 0.49096291
#  0.10760145 0.66808245]
# particular: [1.]
# relev: [0.72093191 0.6930059 ]
# appropri: [0.62596644 0.3416009  0.70105267]
# highli: [1.]
# activ: [0.4581146  0.88889314]
# programm: [1.]
# although: [0.61630826 0.787505  ]
# access: [0.8105318  0.58569463]
# therapi: [0.4538325  0.53295648 0.24766438 0.50827084 0.43625286]
# increas: [1.]
# work: [0.35751863 0.93390601]
# simultan: [0.61630826 0.787505  ]
# expand: [1.]
# prevent: [1.]
# stem: [0.56907382 0.63657962 0.52050108]
# flow: [1.]
# new: [0.5363546  0.29269814 0.60069167 0.51557838]
# real: [1.]
# challeng: [1.]
# genuin: [1.]
# polit: [1.]
# interest: [1.]
# commit: [1.]
# essenti: [0.34706275 0.67341599 0.15437744 0.32244352 0.18939825 0.38869379
#  0.33361893]
# foundat: [1.]
# success: [1.]
# demand: [1.]
# advocaci: [1.]
# level: [0.49371793 0.57979577 0.44088637 0.47507756]
# drive: [1.]
# polici: [1.]
# suffici: [1.]
# resourc: [1.]
# action: [1.]
# relationship: [1.]
# complex: [1.]
# multifacet: [1.]
# cure: [1.]
# shown: [1.]
# promis: [0.50172947 0.37891027 0.77762108]
# potenti: [0.09181508 0.15560867 0.11621598 0.11946029 0.11804796 0.06933951
#  0.14230246 0.55729616 0.12213932 0.75834604]
# boost: [0.4058852  0.50159109 0.54048999 0.53993903]
# crucial: [0.41731547 0.31516012 0.64678942 0.55514443]
# emphas: [1.]
# substitut: [0.41731547 0.31516012 0.64678942 0.55514443]
# convent: [0.15324131 0.11572911 0.23750583 0.93013911 0.20385312]
# profession: [0.11497442 0.57050046 0.17798531 0.5301824  0.14208487 0.15310369
#  0.07077435 0.14553018 0.14959284 0.14782426 0.38373816 0.29535752]
# cultur: [0.60938773 0.79287237]
# reli: [0.3915313  0.69234193 0.60610717]
# centuri: [0.33349041 0.44408671 0.56520127 0.43390327 0.42877338]
# set: [1.]
# often: [0.24683334 0.40114259 0.30503551 0.32869133 0.41833442 0.63408957]
# turn: [1.]
# due: [0.18534212 0.90250546 0.22904495 0.31411878]
# afford: [1.]
# benefit: [0.10841282 0.13397607 0.14436605 0.18373861 0.13722476 0.14105556
#  0.13938791 0.08187426 0.16802699 0.14421889 0.89543498]
# possess: [1.]
# properti: [0.30533045 0.37732599 0.18795106 0.51747564 0.3864755  0.39726445
#  0.39256773]
# benefici: [0.57918014 0.35652362 0.73310386]
# antimicrobi: [1.]
# like: [0.18717791 0.33098534 0.50260736 0.30880806 0.30419325 0.24925222
#  0.11522037 0.23692258 0.24353657 0.24065732 0.14135832 0.29010354
#  0.24899814]
# garlic: [1.]
# echinacea: [1.]
# antivir: [1.]
# antibacteri: [0.46453204 0.28595015 0.58798672 0.59725548]
# common: [0.19917525 0.72001024 0.66476649]
# turmer: [1.]
# ginger: [1.]
# could: [1.]
# inflamm: [0.39151161 0.52134965 0.24100125 0.49556029 0.5208182 ]
# support: [0.11459469 0.1416156  0.0705406  0.14504954 0.14733603 0.15244248
#  0.94649412]
# astragalu: [1.]
# reishi: [1.]
# mushroom: [1.]
# believ: [0.33105341 0.4091143  0.20378524 0.56107104 0.43073251 0.4256401 ]
# consider: [0.27153735 0.46020291 0.3437015  0.35329636 0.34911945 0.20506727
#  0.42085065 0.36121941]
# limit: [0.58660239 0.72492057 0.36109251]
# scientif: [0.41731547 0.31516012 0.64678942 0.55514443]
# evid: [0.41731547 0.31516012 0.64678942 0.55514443]
# research: [0.28175967 0.34819731 0.17344168 0.35664051 0.36659657 0.36226243
#  0.21278725 0.43669402 0.3748179 ]
# earli: [1.]
# rigor: [1.]
# clinic: [1.]
# trial: [1.]
# confirm: [0.49225505 0.87045101]
# efficaci: [1.]
# safeti: [0.11264483 0.19091105 0.14258148 0.14656182 0.14482907 0.14984863
#  0.93038927]
# interact: [0.41731547 0.31516012 0.64678942 0.55514443]
# advers: [1.]
# alway: [0.1020309  0.50627501 0.15794819 0.47049586 0.49682958 0.06280676
#  0.12914678 0.13275207 0.13118259 0.34053792 0.26210694]
# consult: [0.08295716 0.41163153 0.12842122 0.38254096 0.05106561 0.10500397
#  0.10793529 0.1066592  0.27687747 0.21310845 0.06264994 0.12857374
#  0.11035585 0.68518412]
# healthcar: [0.11497442 0.57050046 0.17798531 0.5301824  0.14208487 0.15310369
#  0.07077435 0.14553018 0.14959284 0.14782426 0.38373816 0.29535752]
# alongsid: [0.37089748 0.45835342 0.28010487 0.57484704 0.49339573]
# dosag: [0.11365277 0.56394244 0.17593934 0.52408785 0.14045157 0.15134374
#  0.06996078 0.14385729 0.14787324 0.14612499 0.37932701 0.29196233
#  0.15118946]
# qualiti: [0.35983384 0.22150149 0.45546378 0.27174951 0.55769972 0.47867804]
# proper: [0.11413983 0.56635921 0.17669333 0.52633383 0.18549499 0.0702606
#  0.14447379 0.14850695 0.14675121 0.38095262 0.29321353 0.15183738]
# control: [0.34899774 0.93712357]
# qualifi: [0.41731547 0.31516012 0.64678942 0.55514443]
# practition: [0.41731547 0.31516012 0.64678942 0.55514443]
# familiar: [0.49225505 0.87045101]
# ensur: [0.60088166 0.79933799]
# safe: [0.15590304 0.19266427 0.20760558 0.94629522]
# usag: [1.]
# overal: [0.14856091 0.24509733 0.19782856 0.11219444 0.23025177 0.90173019]
# hold: [1.]
# replac: [0.34537762 0.56129239 0.26083206 0.53529429 0.45944729]
# open: [1.]
# commun: [1.]
# vital: [0.38649683 0.63764647 0.29188562 0.59902418]
# integr: [0.79800058 0.60265669]
# plan: [1.]
# sexual: [0.93835946 0.34566099]
# breast: [1.]
# milk: [1.]
# weaken: [1.]
# hard: [1.]
# germ: [1.]
# virus: [1.]
# fungi: [1.]
# invad: [1.]
# mainli: [1.]
# unprotect: [1.]
# needl: [1.]
# acquir: [1.]
# defici: [0.56333626 0.75882235 0.19257991 0.2641096 ]
# syndrom: [1.]
# condit: [0.39354719 0.2923262  0.17960877 0.51104509 0.53011394 0.1769247
#  0.13453649 0.14496993 0.0670144  0.18450719 0.1416456  0.08221674
#  0.16872985 0.14482216]
# come: [0.9192578  0.39365607]
# sick: [1.]
# rememb: [0.85658607 0.17895114 0.36725365 0.31521669]
# also: [0.65512823 0.32046246 0.29899026 0.29452216 0.24132785 0.11155721
#  0.30714454 0.2293902  0.23579391 0.13686417]
# famili: [0.49078913 0.35131172 0.35684963 0.71299681]
# genera: [1.]
# acacia: [0.32206981 0.90375482 0.28195435]
# wide: [0.71633461 0.62711144 0.30593457]
# repres: [1.]
# genu: [1.]
# five: [0.9196398  0.39276283]
# frequent: [1.]
# variou: [0.24481889 0.2284151  0.67416546 0.22500167 0.17109502 0.18436362
#  0.08522469 0.17524379 0.18013594 0.17800625 0.35566209 0.10455807
#  0.21457998 0.18417568]
# erythrina: [0.34165553 0.29910057 0.89096035]
# abyssinica: [0.34165553 0.29910057 0.89096035]
# warburgia: [1.]
# ugandensi: [1.]
# zanthoxylum: [0.56700243 0.82371612]
# chalybeum: [0.56700243 0.82371612]
# engl: [0.56700243 0.82371612]
# hockii: [1.]
# milicia: [0.46816276 0.88364225]
# excelsa: [0.46816276 0.88364225]
# welw: [0.46816276 0.88364225]
# alo: [1.]
# vera: [1.]
# albizia: [1.]
# coriaria: [1.]
# azadirachta: [1.]
# indica: [1.]
# psorospermum: [1.]
# febrifugum: [1.]
# vernonia: [1.]
# amygdalina: [1.]
# gymnosporia: [1.]
# senegalensi: [1.]
# mention: [1.]
# high: [0.35251268 0.93580704]
# degre: [1.]
# consensu: [1.]
# tmp: [1.]
# differ: [1.]
# though: [0.81966927 0.57283705]
# geograph: [1.]
# separ: [1.]
# contribut: [1.]
# practic: [0.71600007 0.3057917  0.62756301]
# herbal: [0.75628647 0.32299735 0.56894946]
# engag: [1.]
# encourag: [1.]
# biomed: [1.]
# laboratori: [1.]
# diagnos: [1.]
# serostatu: [1.]
# sign: [1.]
# form: [0.60623902 0.18913507 0.56339527 0.32806762 0.15098566 0.16269476
#  0.07520795 0.20706605 0.15464681 0.15896397 0.15708459]
# boil: [0.71410651 0.22278768 0.66363962]
# drink: [0.69088321 0.21554245 0.64205754 0.17206656 0.18541049]
# alon: [1.]
# kind: [0.67008771 0.20905465 0.62273169 0.16688737 0.17982966 0.08312881
#  0.22887411]
# follow: [0.58028982 0.18103941 0.53927994 0.07198878 0.14802738 0.15215974
#  0.15036081 0.39032282 0.30042564 0.15557209]
# packag: [0.5874422  0.18327082 0.54592685 0.07287608 0.14985189 0.15403519
#  0.15221409 0.39513376 0.30412854]
# instruct: [0.5874422  0.18327082 0.54592685 0.07287608 0.14985189 0.15403519
#  0.15221409 0.39513376 0.30412854]
# guidanc: [0.58028982 0.18103941 0.53927994 0.07198878 0.14802738 0.15215974
#  0.15036081 0.39032282 0.30042564 0.15557209]
# ressourc: [0.48058696 0.14993401 0.44662321 0.26007072 0.15979061 0.45465601
#  0.47162078 0.1574027 ]
# data: [0.71410651 0.22278768 0.66363962]
# descript: [0.42076348 0.90717038]
# look: [1.]
# varieti: [1.]
# shape: [0.68425759 0.72924039]
# rang: [0.42092308 0.44859438 0.44189061 0.36207975 0.34959424 0.20534616
#  0.36171066]
# sprawl: [1.]
# shrub: [0.43852371 0.37721989 0.36856978 0.72770765]
# tower: [1.]
# tree: [0.33134107 0.27848506 0.71437473 0.54984354]
# feet: [1.]
# meter: [0.42076348 0.90717038]
# height: [1.]
# bipinn: [1.]
# leav: [0.29871566 0.25695643 0.24424569 0.25106411 0.24809587 0.64403403
#  0.49570335]
# mean: [1.]
# divid: [1.]
# smaller: [1.]
# leaflet: [1.]
# arrang: [1.]
# pair: [1.]
# along: [1.]
# central: [1.]
# stalk: [1.]
# lack: [0.57939967 0.28265852 0.58008779 0.4978939 ]
# altogeth: [1.]
# photosynthesi: [1.]
# green: [0.76927634 0.63891621]
# flame: [1.]
# commonli: [0.51613837 0.85650521]
# lucki: [1.]
# bean: [1.]
# coral: [1.]
# stun: [1.]
# legumin: [1.]
# nativ: [0.30859998 0.26545896 0.25232763 0.2563052  0.66534471 0.51210587]
# east: [0.51613837 0.85650521]
# southern: [1.]
# renown: [0.73234569 0.29121104 0.61552085]
# vibrant: [1.]
# scarlet: [1.]
# flower: [0.34394755 0.29586509 0.28122967 0.28908054 0.28566284 0.74155444]
# resembl: [1.]
# erupt: [1.]
# across: [0.67441473 0.73835275]
# canopi: [1.]
# bloom: [0.42076348 0.90717038]
# season: [1.]
# io: [1.]
# hour: [0.31825126 0.9480064 ]
# three: [0.31825126 0.9480064 ]
# tablespoon: [0.31825126 0.9480064 ]
# thyroid: [0.33669735 0.20687094 0.5886148  0.61057804 0.20377947 0.1549573
#  0.1669744  0.07718628 0.15871476]
# gland: [0.46294109 0.28443662 0.83951257]
# locat: [1.]
# neck: [0.85202794 0.52349631]
# produc: [0.47491549 0.29179384 0.83024794]
# hormon: [0.44517273 0.27351953 0.77825161 0.26943206 0.22076933]
# regul: [0.77796601 0.47799176 0.17834504 0.36672307]
# metabol: [0.85202794 0.52349631]
# heart: [0.7750213  0.47618249 0.17766998 0.37553375]
# temperatur: [0.85202794 0.52349631]
# mood: [0.76650574 0.47095043 0.21557974 0.37973679]
# engin: [0.47491549 0.29179384 0.83024794]
# unit: [1.]
# influenc: [1.]
# virtual: [1.]
# everi: [1.]
# organ: [1.]
# deeper: [0.90454015 0.42638847]
# dive: [0.78250249 0.49389118 0.37915874]
# fascin: [0.8960653  0.44392226]
# function: [0.69723434 0.32088626 0.34577131 0.15983768 0.3286672  0.19609716
#  0.34541885]
# product: [0.83177367 0.5034147  0.23393634]
# primarili: [1.]
# thyroxin: [1.]
# main: [0.96265094 0.27074558]
# storag: [1.]
# convert: [1.]
# triiodothyronin: [1.]
# american: [0.34578874 0.2124568  0.60450837 0.62706466 0.20928185 0.07927044
#  0.16300032]
# provid: [0.35161272 0.21603512 0.61468987 0.63762606 0.2128067 ]
# comprehens: [0.35161272 0.21603512 0.61468987 0.63762606 0.2128067 ]
# diagnosi: [0.33813426 0.2077538  0.59112681 0.61318378 0.20464913 0.09510026
#  0.19517013 0.16751606]
# unravel: [1.]
# butterfli: [1.]
# secret: [0.78520328 0.61923808]
# nestl: [1.]
# play: [1.]
# role: [1.]
# symphoni: [1.]
# delic: [1.]
# maestro: [1.]
# tune: [1.]
# emerg: [1.]
# health: [0.15164125 0.11358734 0.12239615 0.05657935 0.15577692 0.11958946
#  0.06941449 0.55789875 0.12227139 0.75916602]
# let: [0.50811995 0.52197777 0.38983791 0.40072072 0.39598313]
# delv: [0.67482199 0.51773443 0.52589576]
# disord: [1.]
# explor: [0.15344344 0.15762826 0.1177243  0.12101073 0.11958006 0.56452911
#  0.76818834]
# type: [0.90926402 0.41621982]
# option: [0.71240986 0.70176363]
# addit: [0.60668784 0.59762152 0.22636325 0.47279811]
# hypothyroid: [0.62851877 0.61912621 0.47079389]
# underperform: [1.]
# insuffici: [1.]
# lead: [0.33157207 0.94342989]
# imagin: [1.]
# sluggish: [1.]
# struggl: [1.]
# power: [0.19587772 0.98062833]
# way: [1.]
# energi: [0.6425457  0.48130081 0.51862618 0.29412827]
# gain: [1.]
# difficulti: [0.32089366 0.94711523]
# lose: [1.]
# weight: [0.30553426 0.86934388 0.22886136 0.31386701]
# cold: [1.]
# skin: [0.61823053 0.46308745 0.63509136]
# hair: [1.]
# swing: [1.]
# heavi: [1.]
# menstrual: [0.76076225 0.28385044 0.58366919]
# period: [1.]
# hyperthyroid: [0.88082986 0.30494483 0.11550505 0.24413829 0.24125192]
# contrast: [1.]
# overenthusiast: [1.]
# excess: [0.94497208 0.32715098]
# think: [1.]
# rev: [1.]
# put: [1.]
# overdr: [1.]
# loss: [0.91300268 0.24035487 0.32962954]
# nervous: [0.95685577 0.12547448 0.26207478]
# heartbeat: [1.]
# palpit: [0.95606576 0.12537089 0.26499131]
# sweat: [1.]
# sleep: [0.89739676 0.1176775  0.24197507 0.24873011 0.24578946]
# goiter: [0.87809327 0.29306226 0.22284943 0.30562207]
# visibl: [1.]
# enlarg: [1.]
# reason: [1.]
# iodin: [0.87809327 0.29306226 0.22284943 0.30562207]
# autoimmun: [1.]
# nodul: [0.9485651  0.31658213]
# symptomat: [1.]
# sometim: [1.]
# swallow: [1.]
# breath: [1.]
# fortun: [1.]
# treatabl: [1.]
# simpl: [1.]
# measur: [1.]
# shed: [1.]
# light: [1.]
# underli: [1.]
# base: [0.4377838  0.89908028]
# avail: [0.48412874 0.36813956 0.39668916 0.18337518 0.37706632 0.3875926
#  0.38301023]
# synthet: [1.]
# levothyroxin: [1.]
# miss: [1.]
# block: [1.]
# radioact: [1.]
# destroy: [1.]
# overact: [1.]
# tissu: [1.]
# case: [1.]
# surgeri: [1.]
# may: [0.64642724 0.49155404 0.52967456 0.24484956]
# depend: [0.45007654 0.3422457  0.3687872  0.1704771  0.35054458 0.36033047
#  0.3560704  0.36841127]
# supplement: [0.90686574 0.42141967]
# recommend: [0.45007654 0.3422457  0.3687872  0.1704771  0.35054458 0.36033047
#  0.3560704  0.36841127]
# aspir: [1.]
# biopsi: [1.]
# determin: [1.]
# benign: [1.]
# cancer: [1.]
# vari: [0.48412874 0.36813956 0.39668916 0.18337518 0.37706632 0.3875926
#  0.38301023]
# result: [1.]
# monitor: [0.66672152 0.50698615 0.54630345]
# offer: [0.43576264 0.46955647 0.26629939 0.54651466 0.46907782]
# exampl: [1.]
# ashwagandha: [0.68023808 0.73299124]
# desir: [0.68023808 0.73299124]
# gener: [0.68023808 0.73299124]
# mg: [0.68023808 0.73299124]
# root: [0.68023808 0.73299124]
# powder: [0.26942122 0.29031511 0.72764402 0.56005671]
# extract: [0.42073248 0.45336071 0.20957241 0.43093453 0.44296461 0.43772759]
# day: [0.68023808 0.73299124]
# higher: [0.68023808 0.73299124]
# dose: [0.68023808 0.73299124]
# specif: [0.52034495 0.56069823 0.31798858 0.56012667]
# ad: [0.68023808 0.73299124]
# food: [0.32118613 0.34609444 0.15998705 0.44048384 0.33416015 0.66766251]
# capsul: [0.68023808 0.73299124]
# conveni: [0.68023808 0.73299124]
# easi: [0.68023808 0.73299124]
# concentr: [0.68023808 0.73299124]
# potenc: [0.68023808 0.73299124]
# tinctur: [0.54187399 0.26991459 0.55501351 0.57050741]
# liquid: [0.68023808 0.73299124]
# dissolv: [0.68023808 0.73299124]
# alcohol: [0.68023808 0.73299124]
# bladderwrack: [0.58917216 0.80800753]
# sourc: [0.14328275 0.19650206 0.15423709 0.95763663]
# studi: [1.]
# eleuthero: [1.]
# siberian: [1.]
# ginseng: [0.68023808 0.73299124]
# fatigu: [1.]
# improv: [0.43023917 0.21430781 0.44067174 0.26292394 0.53958737 0.46313207]
# stress: [0.48354324 0.24085928 0.50307553 0.29549865 0.60643903]
# histor: [0.48579143 0.24197913 0.66622824 0.51146136]
# natur: [0.41631933 0.20737416 0.57095222 0.43831826 0.25441737 0.44814802]
# content: [0.58917216 0.80800753]
# suppos: [0.58917216 0.80800753]
# led: [0.58917216 0.80800753]
# remedi: [0.47602733 0.65283748 0.29090559 0.51242086]
# digest: [0.39624824 0.19737648 0.54342616 0.40585659 0.41718659 0.41225433]
# address: [0.3829563  0.19075559 0.52519721 0.39224234 0.40319227 0.23402885
#  0.4122343 ]
# constip: [0.58917216 0.80800753]
# complaint: [0.48579143 0.24197913 0.66622824 0.51146136]
# bath: [0.58917216 0.80800753]
# sooth: [0.50443963 0.69180292 0.51667144]
# wound: [0.43600259 0.21717865 0.5979464  0.44657491 0.45361451]
# heal: [0.43600259 0.21717865 0.5979464  0.44657491 0.45361451]
# astring: [0.48923201 0.24369292 0.67094675 0.50109505]
# thought: [0.58917216 0.80800753]
# promot: [0.17251515 0.18589387 0.08593207 0.2365922  0.17669835 0.1816311
#  0.17948374 0.10542592 0.21636104 0.84733022]
# ancient: [1.]
# modern: [1.]
# indian: [1.]
# winter: [1.]
# cherri: [1.]
# prize: [1.]
# adaptogen: [1.]
# india: [1.]
# part: [1.]
# southeast: [1.]
# ayurved: [1.]
# appear: [0.3309192  0.4211699  0.31454978 0.32333083 0.3195082  0.63838744]
# oval: [1.]
# yellow: [1.]
# primari: [1.]
# tea: [0.49974463 0.23101403 0.475024   0.48828489 0.48251206]
# relief: [1.]
# anxieti: [0.41957673 0.19395528 0.39882172 0.40995533 0.40510857 0.2379544
#  0.48834346]
# reduct: [0.61127061 0.34666968 0.71145511]
# stamina: [1.]
# cognit: [0.70746727 0.7067461 ]
# memori: [1.]
# fertil: [1.]
# pain: [0.45684238 0.21118185 0.43424397 0.25908885 0.53171678 0.45637669]
# buglewe: [0.4373452  0.89929371]
# tribe: [0.4373452  0.89929371]
# purpos: [0.26670663 0.54841713 0.56372688 0.55706213]
# valu: [0.26670663 0.54841713 0.56372688 0.55706213]
# arthriti: [0.4373452  0.89929371]
# headach: [0.4373452  0.89929371]
# cramp: [0.32290453 0.6639744  0.67444099]
# stomach: [0.210147   0.43211605 0.87699143]
# upset: [0.4373452  0.89929371]
# diarrhea: [0.4373452  0.89929371]
# calm: [0.26670663 0.54841713 0.56372688 0.55706213]
# menstruat: [0.4373452  0.89929371]
# cycl: [0.4373452  0.89929371]
# eas: [0.4373452  0.89929371]
# menopaus: [0.4373452  0.89929371]
# dri: [0.1782474  0.36652229 0.37675422 0.37229998 0.74386709]
# hawthorn: [0.42766474 0.90393743]
# mild: [0.42766474 0.90393743]
# doctor: [0.05819796 0.12301064 0.07140027 0.14653168 0.57385895 0.12576929
#  0.78088401]
# lie: [0.42766474 0.90393743]
# cardiovascular: [0.42766474 0.90393743]
# pressur: [0.42766474 0.90393743]
# lower: [0.42766474 0.90393743]
# disturb: [0.42766474 0.90393743]
# urinari: [0.42766474 0.90393743]
# lemon: [0.43183182 0.90195415]
# balm: [0.43183182 0.90195415]
# relax: [0.27516696 0.57473297 0.3375891  0.69281943]
# insomnia: [0.43183182 0.90195415]
# rest: [0.43183182 0.90195415]
# allevi: [0.43183182 0.90195415]
# bloat: [0.43183182 0.90195415]
# nausea: [0.43183182 0.90195415]
# beverag: [0.20952633 0.43763136 0.87440123]
# refresh: [0.43183182 0.90195415]
# flavor: [0.43183182 0.90195415]
# made: [0.43183182 0.90195415]
# popular: [0.43183182 0.90195415]
# soup: [0.43183182 0.90195415]
# salad: [0.43183182 0.90195415]
# sauc: [0.43183182 0.90195415]
# oil: [0.43183182 0.90195415]
# seawe: [1.]
# surpris: [1.]
# fucu: [1.]
# vesiculosu: [1.]
# brown: [1.]
# found: [0.55069118 0.83470907]
# northern: [1.]
# atlant: [1.]
# pacif: [1.]
# ocean: [1.]
# particularli: [1.]
# coastal: [1.]
# europ: [0.67964903 0.52176446 0.51559582]
# uniqu: [1.]
# featur: [0.60604442 0.45262289 0.46525843 0.45975784]
# leatheri: [1.]
# frond: [1.]
# air: [1.]
# bladder: [1.]
# henc: [1.]
# name: [0.37330922 0.73516138 0.56584271]
# rocki: [1.]
# shore: [1.]
# intertid: [1.]
# zone: [1.]
# dens: [1.]
# underwat: [1.]
# forest: [1.]
# versatil: [0.70155566 0.71261466]
# lycopu: [1.]
# americanu: [1.]
# virginianu: [1.]
# north: [1.]
# long: [1.]
# histori: [1.]
# member: [0.40321408 0.40957017 0.81833409]
# mint: [0.70155566 0.71261466]
# boast: [0.70155566 0.71261466]
# squar: [1.]
# wrinkl: [0.70155566 0.71261466]
# blue: [1.]
# violet: [1.]
# thrive: [0.56902862 0.58491377 0.57799853]
# moist: [1.]
# meadow: [1.]
# streamsid: [1.]
# shadi: [1.]
# woodland: [0.40240247 0.41363603 0.8166869 ]
# thorni: [1.]
# distinct: [0.711299   0.70288956]
# red: [1.]
# berri: [1.]
# branch: [1.]
# mainstay: [1.]
# rever: [1.]
# find: [1.]
# within: [0.86486606 0.50200269]
# prickli: [1.]
# spini: [1.]
# lobe: [1.]
# cluster: [0.3632082 0.931708 ]
# white: [0.711299   0.70288956]
# bright: [1.]
# hedgerow: [1.]
# sunni: [0.711299   0.70288956]
# field: [1.]
# lemoni: [1.]
# delight: [1.]
# aroma: [1.]
# culinari: [1.]
# fragrant: [1.]
# scent: [1.]
# garden: [1.]
# readili: [1.]
# creat: [1.]
# verdant: [1.]
# patch: [1.]
# african: [1.]
# teak: [1.]
# iroko: [1.]
# mvule: [1.]
# odum: [1.]
# tule: [1.]
# counterwood: [1.]
# larg: [1.]
# decidu: [0.79244999 0.6099369 ]
# tropic: [1.]
# tall: [1.]
# straight: [1.]
# trunk: [1.]
# smooth: [1.]
# bark: [1.]
# glossi: [1.]
# round: [1.]
# point: [0.83750217 0.18950425 0.38891134 0.33380566]
# tip: [1.]
# fruit: [0.79244999 0.6099369 ]
# drupe: [1.]
# walnut: [1.]
# contain: [1.]
# seed: [1.]
# tsp: [1.]
# knobwood: [1.]
# rutacea: [1.]
# close: [1.]
# relat: [1.]
# citru: [1.]
# aromat: [1.]
# ethiopia: [1.]
# southward: [1.]
# mozambiqu: [1.]
# grassland: [1.]
# termit: [1.]
# mound: [1.]
# shoot: [1.]
# decoct: [1.]
# ailment: [1.]
# problem: [1.]
# fever: [1.]
# toothach: [1.]
# eat: [1.]
# leaf: [1.]
# navig: [1.]
# complementari: [0.34680173 0.71172611 0.61088011]
# approach: [0.34680173 0.71172611 0.61088011]
# cam: [1.]
# encompass: [1.]
# outsid: [1.]
# acupunctur: [1.]
# medit: [0.43803411 0.89895835]
# yoga: [0.43803411 0.89895835]
# vast: [0.49369811 0.86963336]
# valuabl: [0.12064885 0.9696801  0.21251908]
# landscap: [1.]
# caution: [1.]
# awar: [0.49369811 0.86963336]
# categor: [1.]
# group: [1.]
# tai: [1.]
# chi: [1.]
# biofeedback: [1.]
# connect: [1.]
# mind: [1.]
# manipul: [1.]
# chiropract: [1.]
# massag: [1.]
# osteopathi: [1.]
# focu: [1.]
# muscl: [1.]
# bone: [1.]
# joint: [1.]
# physic: [1.]
# vitamin: [1.]
# dietari: [1.]
# substanc: [1.]
# reiki: [1.]
# magnet: [1.]
# involv: [1.]
# concern: [0.49369811 0.86963336]
# chronic: [0.43803411 0.89895835]
# depress: [0.43803411 0.89895835]
# mental: [0.43803411 0.89895835]
# emot: [0.43803411 0.89895835]
# enhanc: [0.1196867  0.2456278  0.96194702]
# outcom: [0.43803411 0.89895835]
# never: [0.34680173 0.71172611 0.61088011]
# risk: [0.34680173 0.71172611 0.61088011]
# carri: [0.43803411 0.89895835]
# back: [0.34680173 0.71172611 0.61088011]
# other: [0.34680173 0.71172611 0.61088011]
# strong: [0.34680173 0.71172611 0.61088011]
# choos: [0.08841386 0.18144793 0.15573818 0.9669567 ]
# reput: [0.08841386 0.18144793 0.15573818 0.9669567 ]
# qualif: [0.34680173 0.71172611 0.61088011]
# seek: [0.34680173 0.71172611 0.61088011]
# licens: [0.43803411 0.89895835]
# conjunct: [1.]
# educ: [1.]
# choic: [1.]
# priorit: [0.97681549 0.21408291]
# collabor: [1.]
# journey: [0.59217578 0.80580881]
# wealth: [1.]
# breakdown: [1.]
# prefer: [1.]
# align: [1.]
# holist: [1.]
# applic: [1.]
# especi: [1.]
# side: [1.]
# conclus: [1.]
# expertis: [1.]
# paramount: [1.]
# enjoy: [1.]
# Word weights saved to C:\Users\poste\Desktop\build\weight-result.txt

# %%
# Display word weights in a clearer format with document numbers
for word, weights in word_weights.items():
    print(f'{word}:')
    doc_scores = tfidf_scores_for_words[word]
    sorted_docs = sorted(doc_scores.items(), key=lambda x: x[0])
    for doc_id, weight in sorted_docs:
        print(f'    Document {doc_id}: {weight:.4f}')
    print()
# Out:
# scale:
#     Document D1:: 0.0075
#
# human:
#     Document D1:: 0.0051
#     Document D3:: 0.0029
#     Document D6:: 0.0063
#
# immunodefici:
#     Document D1:: 0.0060
#     Document D3:: 0.0034
#
# viru:
#     Document D1:: 0.0051
#     Document D3:: 0.0029
#     Document D6:: 0.0063
#
# hiv:
#     Document D1:: 0.0032
#     Document D2:: 0.0032
#     Document D3:: 0.0018
#     Document D4:: 0.0015
#     Document D5:: 0.0011
#     Document D6:: 0.0039
#     Document D7:: 0.0019
#
# epidem:
#     Document D1:: 0.0060
#     Document D4:: 0.0028
#
# exceed:
#     Document D1:: 0.0060
#     Document D9:: 0.0032
#
# expect:
#     Document D1:: 0.0060
#     Document D3:: 0.0034
#
# sinc:
#     Document D1:: 0.0075
#
# identif:
#     Document D1:: 0.0075
#
# year:
#     Document D1:: 0.0060
#     Document D3:: 0.0034
#
# ago:
#     Document D1:: 0.0075
#
# global:
#     Document D1:: 0.0060
#     Document D4:: 0.0028
#
# estim:
#     Document D1:: 0.0075
#
# million:
#     Document D1:: 0.0060
#     Document D2:: 0.0061
#
# peopl:
#     Document D11:: 0.0046
#     Document D1:: 0.0029
#     Document D2:: 0.0029
#     Document D31:: 0.0013
#     Document D3:: 0.0016
#     Document D5:: 0.0010
#     Document D8:: 0.0049
#     Document D9:: 0.0015
#
# current:
#     Document D1:: 0.0060
#     Document D2:: 0.0061
#
# live:
#     Document D11:: 0.0050
#     Document D1:: 0.0032
#     Document D2:: 0.0032
#     Document D5:: 0.0011
#     Document D6:: 0.0039
#     Document D8:: 0.0054
#     Document D9:: 0.0017
#
# alreadi:
#     Document D1:: 0.0060
#     Document D2:: 0.0061
#
# die:
#     Document D1:: 0.0075
#
# worst:
#     Document D1:: 0.0075
#
# center:
#     Document D1:: 0.0075
#
# africa:
#     Document D1:: 0.0039
#     Document D25:: 0.0045
#     Document D26:: 0.0035
#     Document D2:: 0.0040
#     Document D9:: 0.0021
#
# spread:
#     Document D1:: 0.0051
#     Document D3:: 0.0029
#     Document D6:: 0.0063
#
# greater:
#     Document D1:: 0.0075
#
# predict:
#     Document D1:: 0.0075
#
# impact:
#     Document D13:: 0.0034
#     Document D1:: 0.0060
#
# social:
#     Document D1:: 0.0075
#
# capit:
#     Document D1:: 0.0075
#
# popul:
#     Document D1:: 0.0060
#     Document D4:: 0.0028
#
# structur:
#     Document D1:: 0.0075
#
# econom:
#     Document D1:: 0.0075
#
# growth:
#     Document D12:: 0.0047
#     Document D1:: 0.0051
#     Document D4:: 0.0024
#
# respond:
#     Document D1:: 0.0075
#
# aid:
#     Document D1:: 0.0039
#     Document D24:: 0.0017
#     Document D3:: 0.0022
#     Document D5:: 0.0013
#     Document D6:: 0.0049
#
# commensur:
#     Document D1:: 0.0075
#
# imper:
#     Document D1:: 0.0075
#
# tool:
#     Document D1:: 0.0051
#     Document D30:: 0.0106
#     Document D32:: 0.0144
#
# effect:
#     Document D16:: 0.0018
#     Document D18:: 0.0013
#     Document D19:: 0.0015
#     Document D1:: 0.0032
#     Document D31:: 0.0014
#     Document D4:: 0.0015
#     Document D5:: 0.0011
#
# respons:
#     Document D12:: 0.0029
#     Document D18:: 0.0013
#     Document D1:: 0.0032
#     Document D27:: 0.0008
#     Document D28:: 0.0017
#     Document D30:: 0.0066
#     Document D32:: 0.0090
#
# known:
#     Document D19:: 0.0016
#     Document D1:: 0.0035
#     Document D21:: 0.0020
#     Document D22:: 0.0015
#     Document D26:: 0.0031
#     Document D9:: 0.0019
#
# noth:
#     Document D1:: 0.0075
#
# less:
#     Document D1:: 0.0075
#
# sustain:
#     Document D1:: 0.0075
#
# mobil:
#     Document D1:: 0.0060
#     Document D4:: 0.0028
#
# necessari:
#     Document D16:: 0.0022
#     Document D18:: 0.0017
#     Document D19:: 0.0018
#     Document D1:: 0.0039
#     Document D30:: 0.0082
#
# combat:
#     Document D1:: 0.0051
#     Document D20:: 0.0011
#     Document D24:: 0.0022
#
# one:
#     Document D1:: 0.0060
#     Document D3:: 0.0034
#
# seriou:
#     Document D1:: 0.0044
#     Document D27:: 0.0011
#     Document D28:: 0.0024
#     Document D31:: 0.0020
#
# crise:
#     Document D1:: 0.0075
#
# face:
#     Document D1:: 0.0075
#
# develop:
#     Document D12:: 0.0041
#     Document D1:: 0.0044
#     Document D3:: 0.0025
#     Document D4:: 0.0021
#
# refer:
#     Document D1:: 0.0039
#     Document D27:: 0.0010
#     Document D2:: 0.0040
#     Document D3:: 0.0022
#     Document D4:: 0.0019
#
# articl:
#     Document D11:: 0.0056
#     Document D1:: 0.0035
#     Document D2:: 0.0036
#     Document D4:: 0.0017
#     Document D8:: 0.0060
#     Document D9:: 0.0019
#
# publish:
#     Document D1:: 0.0060
#     Document D4:: 0.0028
#
# avril:
#     Document D1:: 0.0075
#
# two:
#     Document D12:: 0.0047
#     Document D2:: 0.0051
#     Document D4:: 0.0024
#
# third:
#     Document D2:: 0.0076
#
# world:
#     Document D12:: 0.0024
#     Document D13:: 0.0015
#     Document D21:: 0.0015
#     Document D22:: 0.0011
#     Document D24:: 0.0012
#     Document D27:: 0.0007
#     Document D2:: 0.0026
#     Document D30:: 0.0054
#     Document D31:: 0.0012
#
# resid:
#     Document D2:: 0.0076
#
# opportunist:
#     Document D11:: 0.0056
#     Document D2:: 0.0036
#     Document D3:: 0.0020
#     Document D5:: 0.0012
#     Document D8:: 0.0060
#     Document D9:: 0.0019
#
# infect:
#     Document D11:: 0.0041
#     Document D20:: 0.0006
#     Document D22:: 0.0011
#     Document D2:: 0.0026
#     Document D3:: 0.0015
#     Document D4:: 0.0012
#     Document D5:: 0.0009
#     Document D8:: 0.0044
#     Document D9:: 0.0014
#
# oi:
#     Document D2:: 0.0061
#     Document D7:: 0.0036
#
# associ:
#     Document D12:: 0.0022
#     Document D13:: 0.0013
#     Document D14:: 0.0038
#     Document D15:: 0.0040
#     Document D16:: 0.0013
#     Document D20:: 0.0005
#     Document D22:: 0.0010
#     Document D24:: 0.0010
#     Document D2:: 0.0024
#     Document D5:: 0.0008
#
# singl:
#     Document D25:: 0.0068
#     Document D2:: 0.0061
#
# import:
#     Document D27:: 0.0010
#     Document D28:: 0.0021
#     Document D2:: 0.0040
#     Document D4:: 0.0019
#     Document D5:: 0.0013
#
# caus:
#     Document D15:: 0.0074
#     Document D16:: 0.0025
#     Document D2:: 0.0045
#     Document D5:: 0.0015
#
# mortal:
#     Document D2:: 0.0076
#
# morbid:
#     Document D2:: 0.0076
#
# among:
#     Document D11:: 0.0062
#     Document D2:: 0.0040
#     Document D7:: 0.0024
#     Document D8:: 0.0067
#     Document D9:: 0.0021
#
# patient:
#     Document D2:: 0.0061
#     Document D7:: 0.0036
#
# poor:
#     Document D2:: 0.0076
#
# countri:
#     Document D2:: 0.0061
#     Document D4:: 0.0028
#
# widespread:
#     Document D2:: 0.0061
#     Document D7:: 0.0036
#
# use:
#     Document D11:: 0.0015
#     Document D18:: 0.0004
#     Document D19:: 0.0004
#     Document D20:: 0.0002
#     Document D21:: 0.0005
#     Document D22:: 0.0004
#     Document D23:: 0.0004
#     Document D24:: 0.0004
#     Document D25:: 0.0011
#     Document D26:: 0.0008
#     Document D27:: 0.0002
#     Document D28:: 0.0005
#     Document D2:: 0.0010
#     Document D30:: 0.0020
#     Document D31:: 0.0004
#     Document D5:: 0.0003
#     Document D7:: 0.0006
#     Document D8:: 0.0016
#     Document D9:: 0.0005
#
# medicin:
#     Document D11:: 0.0011
#     Document D13:: 0.0004
#     Document D16:: 0.0004
#     Document D18:: 0.0003
#     Document D19:: 0.0003
#     Document D20:: 0.0002
#     Document D21:: 0.0004
#     Document D22:: 0.0003
#     Document D23:: 0.0003
#     Document D24:: 0.0003
#     Document D26:: 0.0006
#     Document D27:: 0.0002
#     Document D28:: 0.0004
#     Document D2:: 0.0007
#     Document D30:: 0.0015
#     Document D3:: 0.0004
#     Document D5:: 0.0002
#     Document D6:: 0.0009
#     Document D7:: 0.0004
#     Document D8:: 0.0012
#     Document D9:: 0.0004
#
# plant:
#     Document D11:: 0.0046
#     Document D23:: 0.0013
#     Document D26:: 0.0025
#     Document D2:: 0.0029
#     Document D5:: 0.0010
#     Document D7:: 0.0017
#     Document D8:: 0.0049
#     Document D9:: 0.0015
#
# speci:
#     Document D2:: 0.0051
#     Document D7:: 0.0031
#     Document D9:: 0.0027
#
# manag:
#     Document D16:: 0.0010
#     Document D18:: 0.0008
#     Document D20:: 0.0004
#     Document D21:: 0.0010
#     Document D22:: 0.0008
#     Document D23:: 0.0008
#     Document D24:: 0.0008
#     Document D27:: 0.0005
#     Document D28:: 0.0010
#     Document D2:: 0.0018
#     Document D31:: 0.0008
#     Document D4:: 0.0009
#     Document D5:: 0.0006
#
# uganda:
#     Document D11:: 0.0070
#     Document D2:: 0.0045
#     Document D8:: 0.0075
#     Document D9:: 0.0023
#
# even:
#     Document D13:: 0.0018
#     Document D19:: 0.0015
#     Document D2:: 0.0032
#     Document D3:: 0.0018
#     Document D4:: 0.0015
#     Document D7:: 0.0019
#     Document D9:: 0.0017
#
# antiretrovir:
#     Document D2:: 0.0051
#     Document D4:: 0.0024
#     Document D5:: 0.0017
#
# drug:
#     Document D2:: 0.0051
#     Document D3:: 0.0029
#     Document D5:: 0.0017
#
# arv:
#     Document D2:: 0.0061
#     Document D7:: 0.0036
#
# howev:
#     Document D27:: 0.0009
#     Document D28:: 0.0019
#     Document D2:: 0.0036
#     Document D31:: 0.0016
#     Document D5:: 0.0012
#     Document D9:: 0.0019
#
# much:
#     Document D2:: 0.0076
#
# inform:
#     Document D12:: 0.0022
#     Document D13:: 0.0013
#     Document D14:: 0.0038
#     Document D15:: 0.0040
#     Document D16:: 0.0013
#     Document D27:: 0.0006
#     Document D2:: 0.0024
#     Document D30:: 0.0050
#     Document D31:: 0.0011
#     Document D32:: 0.0067
#
# remain:
#     Document D2:: 0.0061
#     Document D4:: 0.0028
#
# undocu:
#     Document D2:: 0.0076
#
# unverifi:
#     Document D2:: 0.0076
#
# site:
#     Document D2:: 0.0076
#
# nation:
#     Document D2:: 0.0076
#
# librari:
#     Document D2:: 0.0076
#
# indigen:
#     Document D11:: 0.0070
#     Document D2:: 0.0045
#     Document D8:: 0.0075
#     Document D9:: 0.0023
#
# tradit:
#     Document D11:: 0.0023
#     Document D18:: 0.0006
#     Document D19:: 0.0007
#     Document D20:: 0.0003
#     Document D21:: 0.0009
#     Document D22:: 0.0006
#     Document D23:: 0.0007
#     Document D24:: 0.0006
#     Document D26:: 0.0013
#     Document D27:: 0.0004
#     Document D28:: 0.0008
#     Document D2:: 0.0015
#     Document D5:: 0.0005
#     Document D8:: 0.0025
#     Document D9:: 0.0008
#
# knowledg:
#     Document D11:: 0.0056
#     Document D2:: 0.0036
#     Document D32:: 0.0100
#     Document D4:: 0.0017
#     Document D8:: 0.0060
#     Document D9:: 0.0019
#
# herbalist:
#     Document D11:: 0.0050
#     Document D2:: 0.0032
#     Document D31:: 0.0014
#     Document D5:: 0.0011
#     Document D7:: 0.0019
#     Document D8:: 0.0054
#     Document D9:: 0.0017
#
# treat:
#     Document D11:: 0.0041
#     Document D18:: 0.0011
#     Document D21:: 0.0015
#     Document D26:: 0.0023
#     Document D27:: 0.0007
#     Document D2:: 0.0026
#     Document D7:: 0.0016
#     Document D8:: 0.0044
#     Document D9:: 0.0014
#
# attack:
#     Document D3:: 0.0043
#
# cell:
#     Document D12:: 0.0055
#     Document D3:: 0.0034
#
# help:
#     Document D13:: 0.0010
#     Document D16:: 0.0010
#     Document D18:: 0.0008
#     Document D19:: 0.0008
#     Document D20:: 0.0004
#     Document D23:: 0.0008
#     Document D24:: 0.0008
#     Document D27:: 0.0005
#     Document D28:: 0.0010
#     Document D3:: 0.0010
#     Document D5:: 0.0006
#     Document D6:: 0.0022
#     Document D9:: 0.0010
#
# bodi:
#     Document D12:: 0.0032
#     Document D13:: 0.0020
#     Document D14:: 0.0057
#     Document D27:: 0.0009
#     Document D3:: 0.0020
#     Document D6:: 0.0044
#
# fight:
#     Document D3:: 0.0025
#     Document D5:: 0.0015
#     Document D6:: 0.0055
#     Document D9:: 0.0023
#
# make:
#     Document D26:: 0.0039
#     Document D30:: 0.0092
#     Document D3:: 0.0025
#     Document D4:: 0.0021
#
# person:
#     Document D3:: 0.0043
#
# vulner:
#     Document D3:: 0.0043
#
# diseas:
#     Document D13:: 0.0018
#     Document D15:: 0.0053
#     Document D16:: 0.0018
#     Document D18:: 0.0013
#     Document D3:: 0.0018
#     Document D4:: 0.0015
#     Document D6:: 0.0039
#
# contact:
#     Document D3:: 0.0034
#     Document D6:: 0.0074
#
# certain:
#     Document D31:: 0.0023
#     Document D3:: 0.0029
#     Document D5:: 0.0017
#
# bodili:
#     Document D3:: 0.0043
#
# fluid:
#     Document D3:: 0.0034
#     Document D6:: 0.0074
#
# share:
#     Document D3:: 0.0034
#     Document D6:: 0.0074
#
# inject:
#     Document D3:: 0.0034
#     Document D7:: 0.0036
#
# equip:
#     Document D3:: 0.0043
#
# late:
#     Document D3:: 0.0043
#
# stage:
#     Document D3:: 0.0034
#     Document D5:: 0.0020
#
# occur:
#     Document D14:: 0.0071
#     Document D15:: 0.0074
#     Document D3:: 0.0025
#     Document D4:: 0.0021
#
# immun:
#     Document D19:: 0.0020
#     Document D3:: 0.0025
#     Document D5:: 0.0015
#     Document D6:: 0.0055
#
# system:
#     Document D19:: 0.0020
#     Document D3:: 0.0025
#     Document D5:: 0.0015
#     Document D6:: 0.0055
#
# badli:
#     Document D3:: 0.0043
#
# damag:
#     Document D3:: 0.0043
#
# take:
#     Document D25:: 0.0058
#     Document D3:: 0.0029
#     Document D4:: 0.0024
#
# prescrib:
#     Document D3:: 0.0034
#     Document D5:: 0.0020
#
# stop:
#     Document D3:: 0.0034
#     Document D6:: 0.0074
#
# progress:
#     Document D3:: 0.0034
#     Document D5:: 0.0020
#
# consid:
#     Document D18:: 0.0019
#     Document D19:: 0.0020
#     Document D3:: 0.0025
#     Document D5:: 0.0015
#
# number:
#     Document D3:: 0.0043
#
# fall:
#     Document D3:: 0.0043
#
# per:
#     Document D18:: 0.0021
#     Document D19:: 0.0023
#     Document D3:: 0.0029
#
# cubic:
#     Document D3:: 0.0043
#
# millimet:
#     Document D3:: 0.0043
#
# blood:
#     Document D16:: 0.0022
#     Document D20:: 0.0008
#     Document D23:: 0.0018
#     Document D3:: 0.0022
#     Document D6:: 0.0049
#
# someon:
#     Document D3:: 0.0043
#
# healthi:
#     Document D3:: 0.0043
#
# count:
#     Document D3:: 0.0043
#
# regardless:
#     Document D3:: 0.0043
#
# without:
#     Document D3:: 0.0043
#
# typic:
#     Document D26:: 0.0045
#     Document D3:: 0.0029
#     Document D9:: 0.0027
#
# surviv:
#     Document D3:: 0.0043
#
# danger:
#     Document D3:: 0.0034
#     Document D7:: 0.0036
#
# ill:
#     Document D3:: 0.0043
#
# life:
#     Document D27:: 0.0011
#     Document D28:: 0.0024
#     Document D31:: 0.0020
#     Document D3:: 0.0025
#
# treatment:
#     Document D12:: 0.0015
#     Document D13:: 0.0009
#     Document D14:: 0.0026
#     Document D15:: 0.0027
#     Document D16:: 0.0009
#     Document D18:: 0.0007
#     Document D27:: 0.0004
#     Document D28:: 0.0009
#     Document D31:: 0.0007
#     Document D3:: 0.0009
#     Document D4:: 0.0008
#     Document D5:: 0.0006
#     Document D6:: 0.0020
#     Document D7:: 0.0010
#
# still:
#     Document D3:: 0.0029
#     Document D4:: 0.0024
#     Document D5:: 0.0017
#
# lifesav:
#     Document D3:: 0.0043
#
# start:
#     Document D27:: 0.0011
#     Document D28:: 0.0024
#     Document D31:: 0.0020
#     Document D3:: 0.0025
#
# soon:
#     Document D3:: 0.0043
#
# get:
#     Document D13:: 0.0025
#     Document D16:: 0.0025
#     Document D3:: 0.0025
#     Document D6:: 0.0055
#
# experi:
#     Document D31:: 0.0027
#     Document D3:: 0.0034
#
# test:
#     Document D16:: 0.0033
#     Document D3:: 0.0034
#
# mani:
#     Document D13:: 0.0016
#     Document D16:: 0.0016
#     Document D27:: 0.0007
#     Document D28:: 0.0015
#     Document D31:: 0.0013
#     Document D3:: 0.0016
#     Document D5:: 0.0010
#     Document D6:: 0.0036
#
# herb:
#     Document D13:: 0.0005
#     Document D16:: 0.0005
#     Document D18:: 0.0004
#     Document D19:: 0.0004
#     Document D20:: 0.0002
#     Document D21:: 0.0005
#     Document D22:: 0.0004
#     Document D23:: 0.0004
#     Document D24:: 0.0004
#     Document D25:: 0.0010
#     Document D26:: 0.0007
#     Document D27:: 0.0002
#     Document D31:: 0.0004
#     Document D32:: 0.0024
#     Document D3:: 0.0005
#     Document D5:: 0.0003
#     Document D6:: 0.0010
#     Document D7:: 0.0005
#     Document D8:: 0.0014
#     Document D9:: 0.0004
#
# altern:
#     Document D11:: 0.0021
#     Document D13:: 0.0008
#     Document D16:: 0.0007
#     Document D18:: 0.0006
#     Document D19:: 0.0006
#     Document D20:: 0.0003
#     Document D21:: 0.0008
#     Document D27:: 0.0003
#     Document D28:: 0.0007
#     Document D30:: 0.0028
#     Document D3:: 0.0008
#     Document D5:: 0.0005
#     Document D6:: 0.0016
#     Document D7:: 0.0008
#     Document D8:: 0.0023
#     Document D9:: 0.0007
#
# reduc:
#     Document D13:: 0.0018
#     Document D16:: 0.0018
#     Document D20:: 0.0007
#     Document D27:: 0.0008
#     Document D3:: 0.0018
#     Document D5:: 0.0011
#     Document D6:: 0.0039
#
# symptom:
#     Document D13:: 0.0011
#     Document D16:: 0.0011
#     Document D20:: 0.0004
#     Document D22:: 0.0009
#     Document D23:: 0.0009
#     Document D27:: 0.0005
#     Document D28:: 0.0010
#     Document D31:: 0.0009
#     Document D3:: 0.0011
#     Document D5:: 0.0007
#     Document D6:: 0.0024
#     Document D7:: 0.0012
#
# rid:
#     Document D13:: 0.0025
#     Document D16:: 0.0025
#     Document D3:: 0.0025
#     Document D6:: 0.0055
#
# continu:
#     Document D13:: 0.0025
#     Document D16:: 0.0025
#     Document D3:: 0.0025
#     Document D6:: 0.0055
#
# http:
#     Document D12:: 0.0032
#     Document D13:: 0.0020
#     Document D14:: 0.0057
#     Document D15:: 0.0059
#     Document D16:: 0.0020
#     Document D3:: 0.0020
#
# asia:
#     Document D19:: 0.0020
#     Document D21:: 0.0026
#     Document D24:: 0.0020
#     Document D4:: 0.0021
#
# ie:
#     Document D4:: 0.0036
#
# show:
#     Document D4:: 0.0036
#
# great:
#     Document D4:: 0.0036
#
# divers:
#     Document D19:: 0.0018
#     Document D27:: 0.0010
#     Document D30:: 0.0082
#     Document D31:: 0.0018
#     Document D4:: 0.0019
#
# sever:
#     Document D16:: 0.0028
#     Document D22:: 0.0022
#     Document D4:: 0.0024
#
# time:
#     Document D4:: 0.0028
#     Document D6:: 0.0074
#
# far:
#     Document D4:: 0.0036
#
# includ:
#     Document D13:: 0.0016
#     Document D15:: 0.0048
#     Document D18:: 0.0012
#     Document D19:: 0.0013
#     Document D20:: 0.0006
#     Document D22:: 0.0012
#     Document D26:: 0.0025
#     Document D4:: 0.0014
#
# china:
#     Document D23:: 0.0027
#     Document D4:: 0.0028
#
# indonesia:
#     Document D4:: 0.0036
#
# vietnam:
#     Document D4:: 0.0036
#
# grow:
#     Document D19:: 0.0018
#     Document D21:: 0.0023
#     Document D25:: 0.0045
#     Document D26:: 0.0035
#     Document D4:: 0.0019
#
# factor:
#     Document D4:: 0.0036
#
# affect:
#     Document D4:: 0.0036
#
# rate:
#     Document D12:: 0.0047
#     Document D13:: 0.0029
#     Document D4:: 0.0024
#
# magnitud:
#     Document D4:: 0.0036
#
# preval:
#     Document D4:: 0.0036
#
# size:
#     Document D25:: 0.0058
#     Document D4:: 0.0024
#     Document D9:: 0.0027
#
# sex:
#     Document D4:: 0.0036
#
# worker:
#     Document D4:: 0.0036
#
# frequenc:
#     Document D4:: 0.0036
#
# commerci:
#     Document D4:: 0.0036
#
# view:
#     Document D4:: 0.0036
#
# present:
#     Document D4:: 0.0036
#
# state:
#     Document D4:: 0.0036
#
# low:
#     Document D13:: 0.0034
#     Document D4:: 0.0028
#
# might:
#     Document D16:: 0.0028
#     Document D4:: 0.0024
#     Document D5:: 0.0017
#
# small:
#     Document D19:: 0.0016
#     Document D22:: 0.0015
#     Document D23:: 0.0016
#     Document D24:: 0.0016
#     Document D25:: 0.0040
#     Document D4:: 0.0017
#
# percentag:
#     Document D4:: 0.0036
#
# becom:
#     Document D14:: 0.0096
#     Document D4:: 0.0028
#
# establish:
#     Document D18:: 0.0025
#     Document D4:: 0.0028
#
# need:
#     Document D18:: 0.0019
#     Document D31:: 0.0020
#     Document D4:: 0.0021
#     Document D5:: 0.0015
#
# care:
#     Document D27:: 0.0010
#     Document D28:: 0.0021
#     Document D30:: 0.0082
#     Document D31:: 0.0018
#     Document D4:: 0.0019
#
# unavoid:
#     Document D4:: 0.0036
#
# thailand:
#     Document D4:: 0.0036
#
# cambodia:
#     Document D4:: 0.0036
#
# see:
#     Document D4:: 0.0036
#
# burgeon:
#     Document D4:: 0.0036
#
# manifest:
#     Document D13:: 0.0034
#     Document D4:: 0.0028
#
# region:
#     Document D21:: 0.0035
#     Document D4:: 0.0028
#
# discuss:
#     Document D4:: 0.0036
#
# aim:
#     Document D27:: 0.0015
#     Document D4:: 0.0028
#
# identifi:
#     Document D4:: 0.0036
#
# key:
#     Document D20:: 0.0009
#     Document D23:: 0.0020
#     Document D31:: 0.0020
#     Document D4:: 0.0021
#
# issu:
#     Document D18:: 0.0015
#     Document D20:: 0.0007
#     Document D21:: 0.0020
#     Document D23:: 0.0016
#     Document D24:: 0.0016
#     Document D4:: 0.0017
#
# medic:
#     Document D13:: 0.0005
#     Document D16:: 0.0005
#     Document D18:: 0.0004
#     Document D19:: 0.0004
#     Document D20:: 0.0002
#     Document D21:: 0.0005
#     Document D22:: 0.0004
#     Document D23:: 0.0004
#     Document D24:: 0.0004
#     Document D25:: 0.0010
#     Document D26:: 0.0007
#     Document D27:: 0.0002
#     Document D28:: 0.0004
#     Document D30:: 0.0017
#     Document D31:: 0.0004
#     Document D32:: 0.0024
#     Document D4:: 0.0004
#     Document D5:: 0.0003
#     Document D7:: 0.0005
#     Document D9:: 0.0004
#
# particular:
#     Document D4:: 0.0036
#
# relev:
#     Document D31:: 0.0027
#     Document D4:: 0.0028
#
# appropri:
#     Document D27:: 0.0013
#     Document D28:: 0.0027
#     Document D4:: 0.0024
#
# highli:
#     Document D4:: 0.0036
#
# activ:
#     Document D12:: 0.0055
#     Document D4:: 0.0028
#
# programm:
#     Document D4:: 0.0036
#
# although:
#     Document D4:: 0.0028
#     Document D7:: 0.0036
#
# access:
#     Document D4:: 0.0028
#     Document D5:: 0.0020
#
# therapi:
#     Document D16:: 0.0022
#     Document D27:: 0.0010
#     Document D28:: 0.0021
#     Document D31:: 0.0018
#     Document D4:: 0.0019
#
# increas:
#     Document D4:: 0.0036
#
# work:
#     Document D4:: 0.0028
#     Document D6:: 0.0074
#
# simultan:
#     Document D4:: 0.0028
#     Document D7:: 0.0036
#
# expand:
#     Document D4:: 0.0036
#
# prevent:
#     Document D4:: 0.0036
#
# stem:
#     Document D22:: 0.0022
#     Document D4:: 0.0024
#     Document D9:: 0.0027
#
# flow:
#     Document D4:: 0.0036
#
# new:
#     Document D27:: 0.0011
#     Document D28:: 0.0024
#     Document D31:: 0.0020
#     Document D4:: 0.0021
#
# real:
#     Document D4:: 0.0036
#
# challeng:
#     Document D4:: 0.0036
#
# genuin:
#     Document D4:: 0.0036
#
# polit:
#     Document D4:: 0.0036
#
# interest:
#     Document D4:: 0.0036
#
# commit:
#     Document D4:: 0.0036
#
# essenti:
#     Document D12:: 0.0029
#     Document D20:: 0.0007
#     Document D24:: 0.0014
#     Document D27:: 0.0008
#     Document D28:: 0.0017
#     Document D31:: 0.0014
#     Document D4:: 0.0015
#
# foundat:
#     Document D4:: 0.0036
#
# success:
#     Document D4:: 0.0036
#
# demand:
#     Document D4:: 0.0036
#
# advocaci:
#     Document D4:: 0.0036
#
# level:
#     Document D16:: 0.0025
#     Document D18:: 0.0019
#     Document D19:: 0.0020
#     Document D4:: 0.0021
#
# drive:
#     Document D4:: 0.0036
#
# polici:
#     Document D4:: 0.0036
#
# suffici:
#     Document D4:: 0.0036
#
# resourc:
#     Document D4:: 0.0036
#
# action:
#     Document D4:: 0.0036
#
# relationship:
#     Document D5:: 0.0026
#
# complex:
#     Document D5:: 0.0026
#
# multifacet:
#     Document D5:: 0.0026
#
# cure:
#     Document D5:: 0.0026
#
# shown:
#     Document D5:: 0.0026
#
# promis:
#     Document D27:: 0.0013
#     Document D28:: 0.0027
#     Document D5:: 0.0017
#
# potenti:
#     Document D21:: 0.0014
#     Document D22:: 0.0010
#     Document D23:: 0.0011
#     Document D24:: 0.0010
#     Document D27:: 0.0006
#     Document D28:: 0.0013
#     Document D30:: 0.0050
#     Document D31:: 0.0011
#     Document D32:: 0.0067
#     Document D5:: 0.0008
#
# boost:
#     Document D18:: 0.0019
#     Document D19:: 0.0020
#     Document D31:: 0.0020
#     Document D5:: 0.0015
#
# crucial:
#     Document D27:: 0.0011
#     Document D28:: 0.0024
#     Document D31:: 0.0020
#     Document D5:: 0.0015
#
# emphas:
#     Document D5:: 0.0026
#
# substitut:
#     Document D27:: 0.0011
#     Document D28:: 0.0024
#     Document D31:: 0.0020
#     Document D5:: 0.0015
#
# convent:
#     Document D27:: 0.0010
#     Document D28:: 0.0021
#     Document D30:: 0.0082
#     Document D31:: 0.0018
#     Document D5:: 0.0013
#
# profession:
#     Document D11:: 0.0031
#     Document D18:: 0.0008
#     Document D19:: 0.0009
#     Document D20:: 0.0004
#     Document D22:: 0.0009
#     Document D23:: 0.0009
#     Document D24:: 0.0009
#     Document D25:: 0.0023
#     Document D26:: 0.0017
#     Document D5:: 0.0007
#     Document D8:: 0.0034
#     Document D9:: 0.0010
#
# cultur:
#     Document D23:: 0.0027
#     Document D5:: 0.0020
#
# reli:
#     Document D5:: 0.0017
#     Document D7:: 0.0031
#     Document D9:: 0.0027
#
# centuri:
#     Document D19:: 0.0018
#     Document D21:: 0.0023
#     Document D23:: 0.0018
#     Document D24:: 0.0017
#     Document D5:: 0.0013
#
# set:
#     Document D5:: 0.0026
#
# often:
#     Document D16:: 0.0020
#     Document D18:: 0.0015
#     Document D19:: 0.0016
#     Document D21:: 0.0020
#     Document D26:: 0.0031
#     Document D5:: 0.0012
#
# turn:
#     Document D5:: 0.0026
#
# due:
#     Document D15:: 0.0074
#     Document D18:: 0.0019
#     Document D21:: 0.0026
#     Document D5:: 0.0015
#
# afford:
#     Document D5:: 0.0026
#
# benefit:
#     Document D18:: 0.0009
#     Document D19:: 0.0010
#     Document D21:: 0.0013
#     Document D22:: 0.0009
#     Document D23:: 0.0010
#     Document D24:: 0.0010
#     Document D27:: 0.0006
#     Document D28:: 0.0012
#     Document D31:: 0.0010
#     Document D32:: 0.0061
#     Document D5:: 0.0007
#
# possess:
#     Document D5:: 0.0026
#
# properti:
#     Document D18:: 0.0013
#     Document D20:: 0.0007
#     Document D21:: 0.0018
#     Document D22:: 0.0014
#     Document D23:: 0.0014
#     Document D24:: 0.0014
#     Document D5:: 0.0011
#
# benefici:
#     Document D20:: 0.0011
#     Document D22:: 0.0022
#     Document D5:: 0.0017
#
# antimicrobi:
#     Document D5:: 0.0026
#
# like:
#     Document D12:: 0.0017
#     Document D13:: 0.0010
#     Document D16:: 0.0010
#     Document D19:: 0.0008
#     Document D20:: 0.0004
#     Document D22:: 0.0008
#     Document D23:: 0.0008
#     Document D24:: 0.0008
#     Document D27:: 0.0005
#     Document D28:: 0.0010
#     Document D31:: 0.0008
#     Document D5:: 0.0006
#     Document D7:: 0.0011
#
# garlic:
#     Document D5:: 0.0026
#
# echinacea:
#     Document D5:: 0.0026
#
# antivir:
#     Document D5:: 0.0026
#
# antibacteri:
#     Document D20:: 0.0009
#     Document D22:: 0.0019
#     Document D24:: 0.0020
#     Document D5:: 0.0015
#
# common:
#     Document D25:: 0.0058
#     Document D5:: 0.0017
#     Document D6:: 0.0063
#
# turmer:
#     Document D5:: 0.0026
#
# ginger:
#     Document D5:: 0.0026
#
# could:
#     Document D5:: 0.0026
#
# inflamm:
#     Document D19:: 0.0018
#     Document D20:: 0.0008
#     Document D22:: 0.0017
#     Document D31:: 0.0018
#     Document D5:: 0.0013
#
# support:
#     Document D18:: 0.0013
#     Document D20:: 0.0007
#     Document D22:: 0.0014
#     Document D24:: 0.0014
#     Document D31:: 0.0014
#     Document D32:: 0.0090
#     Document D5:: 0.0011
#
# astragalu:
#     Document D5:: 0.0026
#
# reishi:
#     Document D5:: 0.0026
#
# mushroom:
#     Document D5:: 0.0026
#
# believ:
#     Document D18:: 0.0015
#     Document D20:: 0.0007
#     Document D21:: 0.0020
#     Document D23:: 0.0016
#     Document D24:: 0.0016
#     Document D5:: 0.0012
#
# consider:
#     Document D21:: 0.0017
#     Document D22:: 0.0012
#     Document D23:: 0.0013
#     Document D24:: 0.0013
#     Document D27:: 0.0007
#     Document D28:: 0.0015
#     Document D31:: 0.0013
#     Document D5:: 0.0010
#
# limit:
#     Document D18:: 0.0021
#     Document D20:: 0.0011
#     Document D5:: 0.0017
#
# scientif:
#     Document D27:: 0.0011
#     Document D28:: 0.0024
#     Document D31:: 0.0020
#     Document D5:: 0.0015
#
# evid:
#     Document D27:: 0.0011
#     Document D28:: 0.0024
#     Document D31:: 0.0020
#     Document D5:: 0.0015
#
# research:
#     Document D18:: 0.0011
#     Document D20:: 0.0006
#     Document D22:: 0.0011
#     Document D23:: 0.0012
#     Document D24:: 0.0012
#     Document D27:: 0.0007
#     Document D28:: 0.0014
#     Document D31:: 0.0012
#     Document D5:: 0.0009
#
# earli:
#     Document D5:: 0.0026
#
# rigor:
#     Document D5:: 0.0026
#
# clinic:
#     Document D5:: 0.0026
#
# trial:
#     Document D5:: 0.0026
#
# confirm:
#     Document D5:: 0.0020
#     Document D7:: 0.0036
#
# efficaci:
#     Document D5:: 0.0026
#
# safeti:
#     Document D21:: 0.0018
#     Document D22:: 0.0014
#     Document D23:: 0.0014
#     Document D24:: 0.0014
#     Document D31:: 0.0014
#     Document D32:: 0.0090
#     Document D5:: 0.0011
#
# interact:
#     Document D27:: 0.0011
#     Document D28:: 0.0024
#     Document D31:: 0.0020
#     Document D5:: 0.0015
#
# advers:
#     Document D5:: 0.0026
#
# alway:
#     Document D11:: 0.0034
#     Document D15:: 0.0036
#     Document D20:: 0.0005
#     Document D22:: 0.0009
#     Document D23:: 0.0010
#     Document D24:: 0.0010
#     Document D25:: 0.0025
#     Document D26:: 0.0019
#     Document D5:: 0.0007
#     Document D8:: 0.0037
#     Document D9:: 0.0011
#
# consult:
#     Document D11:: 0.0026
#     Document D20:: 0.0003
#     Document D22:: 0.0007
#     Document D23:: 0.0007
#     Document D24:: 0.0007
#     Document D25:: 0.0019
#     Document D26:: 0.0014
#     Document D27:: 0.0004
#     Document D28:: 0.0009
#     Document D31:: 0.0007
#     Document D32:: 0.0046
#     Document D5:: 0.0006
#     Document D8:: 0.0028
#     Document D9:: 0.0009
#
# healthcar:
#     Document D11:: 0.0031
#     Document D18:: 0.0008
#     Document D19:: 0.0009
#     Document D20:: 0.0004
#     Document D22:: 0.0009
#     Document D23:: 0.0009
#     Document D24:: 0.0009
#     Document D25:: 0.0023
#     Document D26:: 0.0017
#     Document D5:: 0.0007
#     Document D8:: 0.0034
#     Document D9:: 0.0010
#
# alongsid:
#     Document D18:: 0.0017
#     Document D27:: 0.0010
#     Document D28:: 0.0021
#     Document D31:: 0.0018
#     Document D5:: 0.0013
#
# dosag:
#     Document D11:: 0.0028
#     Document D18:: 0.0008
#     Document D19:: 0.0008
#     Document D20:: 0.0004
#     Document D22:: 0.0008
#     Document D23:: 0.0008
#     Document D24:: 0.0008
#     Document D25:: 0.0021
#     Document D26:: 0.0016
#     Document D31:: 0.0008
#     Document D5:: 0.0006
#     Document D8:: 0.0031
#     Document D9:: 0.0010
#
# qualiti:
#     Document D20:: 0.0007
#     Document D22:: 0.0015
#     Document D27:: 0.0009
#     Document D28:: 0.0019
#     Document D31:: 0.0016
#     Document D5:: 0.0012
#
# proper:
#     Document D11:: 0.0031
#     Document D16:: 0.0011
#     Document D20:: 0.0004
#     Document D22:: 0.0009
#     Document D23:: 0.0009
#     Document D24:: 0.0009
#     Document D25:: 0.0023
#     Document D26:: 0.0017
#     Document D31:: 0.0009
#     Document D5:: 0.0007
#     Document D8:: 0.0034
#     Document D9:: 0.0010
#
# control:
#     Document D12:: 0.0055
#     Document D5:: 0.0020
#
# qualifi:
#     Document D27:: 0.0011
#     Document D28:: 0.0024
#     Document D31:: 0.0020
#     Document D5:: 0.0015
#
# practition:
#     Document D27:: 0.0011
#     Document D28:: 0.0024
#     Document D31:: 0.0020
#     Document D5:: 0.0015
#
# familiar:
#     Document D5:: 0.0020
#     Document D7:: 0.0036
#
# ensur:
#     Document D31:: 0.0027
#     Document D5:: 0.0020
#
# safe:
#     Document D18:: 0.0019
#     Document D19:: 0.0020
#     Document D30:: 0.0092
#     Document D5:: 0.0015
#
# usag:
#     Document D5:: 0.0026
#
# overal:
#     Document D13:: 0.0020
#     Document D19:: 0.0016
#     Document D27:: 0.0009
#     Document D28:: 0.0019
#     Document D30:: 0.0073
#     Document D5:: 0.0012
#
# hold:
#     Document D5:: 0.0026
#
# replac:
#     Document D16:: 0.0022
#     Document D27:: 0.0010
#     Document D28:: 0.0021
#     Document D31:: 0.0018
#     Document D5:: 0.0013
#
# open:
#     Document D5:: 0.0026
#
# commun:
#     Document D5:: 0.0026
#
# vital:
#     Document D13:: 0.0025
#     Document D27:: 0.0011
#     Document D28:: 0.0024
#     Document D5:: 0.0015
#
# integr:
#     Document D27:: 0.0015
#     Document D5:: 0.0020
#
# plan:
#     Document D5:: 0.0026
#
# sexual:
#     Document D19:: 0.0027
#     Document D6:: 0.0074
#
# breast:
#     Document D6:: 0.0093
#
# milk:
#     Document D6:: 0.0093
#
# weaken:
#     Document D6:: 0.0093
#
# hard:
#     Document D6:: 0.0093
#
# germ:
#     Document D6:: 0.0093
#
# virus:
#     Document D6:: 0.0093
#
# fungi:
#     Document D6:: 0.0093
#
# invad:
#     Document D6:: 0.0093
#
# mainli:
#     Document D6:: 0.0093
#
# unprotect:
#     Document D6:: 0.0093
#
# needl:
#     Document D6:: 0.0093
#
# acquir:
#     Document D6:: 0.0093
#
# defici:
#     Document D15:: 0.0074
#     Document D18:: 0.0019
#     Document D21:: 0.0026
#     Document D6:: 0.0055
#
# syndrom:
#     Document D6:: 0.0093
#
# condit:
#     Document D12:: 0.0015
#     Document D13:: 0.0009
#     Document D14:: 0.0026
#     Document D15:: 0.0027
#     Document D16:: 0.0009
#     Document D18:: 0.0007
#     Document D19:: 0.0007
#     Document D20:: 0.0003
#     Document D21:: 0.0009
#     Document D23:: 0.0007
#     Document D27:: 0.0004
#     Document D28:: 0.0009
#     Document D31:: 0.0007
#     Document D6:: 0.0020
#
# come:
#     Document D6:: 0.0074
#     Document D9:: 0.0032
#
# sick:
#     Document D6:: 0.0093
#
# rememb:
#     Document D27:: 0.0011
#     Document D28:: 0.0024
#     Document D31:: 0.0020
#     Document D6:: 0.0055
#
# also:
#     Document D13:: 0.0013
#     Document D16:: 0.0013
#     Document D19:: 0.0011
#     Document D20:: 0.0005
#     Document D21:: 0.0014
#     Document D22:: 0.0010
#     Document D23:: 0.0011
#     Document D27:: 0.0006
#     Document D6:: 0.0029
#     Document D7:: 0.0014
#
# famili:
#     Document D22:: 0.0019
#     Document D24:: 0.0020
#     Document D26:: 0.0039
#     Document D7:: 0.0027
#
# genera:
#     Document D7:: 0.0046
#
# acacia:
#     Document D7:: 0.0031
#     Document D8:: 0.0086
#     Document D9:: 0.0027
#
# wide:
#     Document D27:: 0.0013
#     Document D7:: 0.0031
#     Document D9:: 0.0027
#
# repres:
#     Document D7:: 0.0046
#
# genu:
#     Document D7:: 0.0046
#
# five:
#     Document D27:: 0.0015
#     Document D7:: 0.0036
#
# frequent:
#     Document D7:: 0.0046
#
# variou:
#     Document D13:: 0.0009
#     Document D15:: 0.0027
#     Document D16:: 0.0009
#     Document D18:: 0.0007
#     Document D19:: 0.0007
#     Document D20:: 0.0003
#     Document D22:: 0.0007
#     Document D23:: 0.0007
#     Document D24:: 0.0007
#     Document D26:: 0.0014
#     Document D27:: 0.0004
#     Document D28:: 0.0009
#     Document D31:: 0.0007
#     Document D7:: 0.0010
#
# erythrina:
#     Document D11:: 0.0080
#     Document D7:: 0.0031
#     Document D9:: 0.0027
#
# abyssinica:
#     Document D11:: 0.0080
#     Document D7:: 0.0031
#     Document D9:: 0.0027
#
# warburgia:
#     Document D7:: 0.0046
#
# ugandensi:
#     Document D7:: 0.0046
#
# zanthoxylum:
#     Document D26:: 0.0053
#     Document D7:: 0.0036
#
# chalybeum:
#     Document D26:: 0.0053
#     Document D7:: 0.0036
#
# engl:
#     Document D26:: 0.0053
#     Document D7:: 0.0036
#
# hockii:
#     Document D7:: 0.0046
#
# milicia:
#     Document D25:: 0.0068
#     Document D7:: 0.0036
#
# excelsa:
#     Document D25:: 0.0068
#     Document D7:: 0.0036
#
# welw:
#     Document D25:: 0.0068
#     Document D7:: 0.0036
#
# alo:
#     Document D7:: 0.0046
#
# vera:
#     Document D7:: 0.0046
#
# albizia:
#     Document D7:: 0.0046
#
# coriaria:
#     Document D7:: 0.0046
#
# azadirachta:
#     Document D7:: 0.0046
#
# indica:
#     Document D7:: 0.0046
#
# psorospermum:
#     Document D7:: 0.0046
#
# febrifugum:
#     Document D7:: 0.0046
#
# vernonia:
#     Document D7:: 0.0046
#
# amygdalina:
#     Document D7:: 0.0046
#
# gymnosporia:
#     Document D7:: 0.0046
#
# senegalensi:
#     Document D7:: 0.0046
#
# mention:
#     Document D7:: 0.0046
#
# high:
#     Document D14:: 0.0096
#     Document D7:: 0.0036
#
# degre:
#     Document D7:: 0.0046
#
# consensu:
#     Document D7:: 0.0046
#
# tmp:
#     Document D7:: 0.0046
#
# differ:
#     Document D7:: 0.0046
#
# though:
#     Document D18:: 0.0025
#     Document D7:: 0.0036
#
# geograph:
#     Document D7:: 0.0046
#
# separ:
#     Document D7:: 0.0046
#
# contribut:
#     Document D7:: 0.0046
#
# practic:
#     Document D27:: 0.0013
#     Document D28:: 0.0027
#     Document D7:: 0.0031
#
# herbal:
#     Document D27:: 0.0013
#     Document D31:: 0.0023
#     Document D7:: 0.0031
#
# engag:
#     Document D7:: 0.0046
#
# encourag:
#     Document D7:: 0.0046
#
# biomed:
#     Document D7:: 0.0046
#
# laboratori:
#     Document D7:: 0.0046
#
# diagnos:
#     Document D7:: 0.0046
#
# serostatu:
#     Document D7:: 0.0046
#
# sign:
#     Document D7:: 0.0046
#
# form:
#     Document D11:: 0.0034
#     Document D12:: 0.0020
#     Document D18:: 0.0009
#     Document D19:: 0.0010
#     Document D20:: 0.0005
#     Document D21:: 0.0013
#     Document D22:: 0.0009
#     Document D23:: 0.0010
#     Document D24:: 0.0010
#     Document D8:: 0.0037
#     Document D9:: 0.0011
#
# boil:
#     Document D11:: 0.0080
#     Document D8:: 0.0086
#     Document D9:: 0.0027
#
# drink:
#     Document D11:: 0.0062
#     Document D18:: 0.0017
#     Document D19:: 0.0018
#     Document D8:: 0.0067
#     Document D9:: 0.0021
#
# alon:
#     Document D8:: 0.0128
#
# kind:
#     Document D11:: 0.0050
#     Document D18:: 0.0013
#     Document D19:: 0.0015
#     Document D20:: 0.0007
#     Document D21:: 0.0018
#     Document D8:: 0.0054
#     Document D9:: 0.0017
#
# follow:
#     Document D11:: 0.0038
#     Document D20:: 0.0005
#     Document D22:: 0.0010
#     Document D23:: 0.0011
#     Document D24:: 0.0010
#     Document D25:: 0.0027
#     Document D26:: 0.0021
#     Document D31:: 0.0011
#     Document D8:: 0.0040
#     Document D9:: 0.0013
#
# packag:
#     Document D11:: 0.0041
#     Document D20:: 0.0006
#     Document D22:: 0.0011
#     Document D23:: 0.0012
#     Document D24:: 0.0012
#     Document D25:: 0.0030
#     Document D26:: 0.0023
#     Document D8:: 0.0044
#     Document D9:: 0.0014
#
# instruct:
#     Document D11:: 0.0041
#     Document D20:: 0.0006
#     Document D22:: 0.0011
#     Document D23:: 0.0012
#     Document D24:: 0.0012
#     Document D25:: 0.0030
#     Document D26:: 0.0023
#     Document D8:: 0.0044
#     Document D9:: 0.0014
#
# guidanc:
#     Document D11:: 0.0038
#     Document D20:: 0.0005
#     Document D22:: 0.0010
#     Document D23:: 0.0011
#     Document D24:: 0.0010
#     Document D25:: 0.0027
#     Document D26:: 0.0021
#     Document D31:: 0.0011
#     Document D8:: 0.0040
#     Document D9:: 0.0013
#
# ressourc:
#     Document D11:: 0.0046
#     Document D12:: 0.0026
#     Document D13:: 0.0016
#     Document D14:: 0.0046
#     Document D15:: 0.0048
#     Document D16:: 0.0016
#     Document D8:: 0.0049
#     Document D9:: 0.0015
#
# data:
#     Document D11:: 0.0080
#     Document D8:: 0.0086
#     Document D9:: 0.0027
#
# descript:
#     Document D25:: 0.0068
#     Document D9:: 0.0032
#
# look:
#     Document D9:: 0.0040
#
# varieti:
#     Document D9:: 0.0040
#
# shape:
#     Document D13:: 0.0034
#     Document D9:: 0.0032
#
# rang:
#     Document D13:: 0.0018
#     Document D16:: 0.0018
#     Document D19:: 0.0015
#     Document D24:: 0.0014
#     Document D27:: 0.0008
#     Document D31:: 0.0014
#     Document D9:: 0.0017
#
# sprawl:
#     Document D9:: 0.0040
#
# shrub:
#     Document D19:: 0.0020
#     Document D23:: 0.0020
#     Document D26:: 0.0039
#     Document D9:: 0.0023
#
# tower:
#     Document D9:: 0.0040
#
# tree:
#     Document D23:: 0.0020
#     Document D25:: 0.0051
#     Document D26:: 0.0039
#     Document D9:: 0.0023
#
# feet:
#     Document D9:: 0.0040
#
# meter:
#     Document D25:: 0.0068
#     Document D9:: 0.0032
#
# height:
#     Document D9:: 0.0040
#
# bipinn:
#     Document D9:: 0.0040
#
# leav:
#     Document D19:: 0.0015
#     Document D22:: 0.0014
#     Document D23:: 0.0014
#     Document D24:: 0.0014
#     Document D25:: 0.0036
#     Document D26:: 0.0028
#     Document D9:: 0.0017
#
# mean:
#     Document D9:: 0.0040
#
# divid:
#     Document D9:: 0.0040
#
# smaller:
#     Document D9:: 0.0040
#
# leaflet:
#     Document D9:: 0.0040
#
# arrang:
#     Document D9:: 0.0040
#
# pair:
#     Document D9:: 0.0040
#
# along:
#     Document D9:: 0.0040
#
# central:
#     Document D9:: 0.0040
#
# stalk:
#     Document D9:: 0.0040
#
# lack:
#     Document D27:: 0.0011
#     Document D28:: 0.0024
#     Document D31:: 0.0020
#     Document D9:: 0.0023
#
# altogeth:
#     Document D9:: 0.0040
#
# photosynthesi:
#     Document D9:: 0.0040
#
# green:
#     Document D24:: 0.0026
#     Document D9:: 0.0032
#
# flame:
#     Document D9:: 0.0040
#
# commonli:
#     Document D26:: 0.0053
#     Document D9:: 0.0032
#
# lucki:
#     Document D9:: 0.0040
#
# bean:
#     Document D9:: 0.0040
#
# coral:
#     Document D9:: 0.0040
#
# stun:
#     Document D9:: 0.0040
#
# legumin:
#     Document D9:: 0.0040
#
# nativ:
#     Document D19:: 0.0016
#     Document D22:: 0.0015
#     Document D24:: 0.0016
#     Document D25:: 0.0040
#     Document D26:: 0.0031
#     Document D9:: 0.0019
#
# east:
#     Document D26:: 0.0053
#     Document D9:: 0.0032
#
# southern:
#     Document D9:: 0.0040
#
# renown:
#     Document D20:: 0.0011
#     Document D23:: 0.0023
#     Document D9:: 0.0027
#
# vibrant:
#     Document D9:: 0.0040
#
# scarlet:
#     Document D9:: 0.0040
#
# flower:
#     Document D19:: 0.0016
#     Document D22:: 0.0015
#     Document D23:: 0.0016
#     Document D24:: 0.0016
#     Document D25:: 0.0040
#     Document D9:: 0.0019
#
# resembl:
#     Document D9:: 0.0040
#
# erupt:
#     Document D9:: 0.0040
#
# across:
#     Document D21:: 0.0035
#     Document D9:: 0.0032
#
# canopi:
#     Document D9:: 0.0040
#
# bloom:
#     Document D25:: 0.0068
#     Document D9:: 0.0032
#
# season:
#     Document D9:: 0.0040
#
# io:
#     Document D9:: 0.0040
#
# hour:
#     Document D11:: 0.0094
#     Document D9:: 0.0032
#
# three:
#     Document D11:: 0.0094
#     Document D9:: 0.0032
#
# tablespoon:
#     Document D11:: 0.0094
#     Document D9:: 0.0032
#
# thyroid:
#     Document D12:: 0.0024
#     Document D13:: 0.0015
#     Document D14:: 0.0042
#     Document D15:: 0.0044
#     Document D16:: 0.0015
#     Document D18:: 0.0011
#     Document D19:: 0.0012
#     Document D20:: 0.0006
#     Document D22:: 0.0011
#
# gland:
#     Document D12:: 0.0047
#     Document D13:: 0.0029
#     Document D15:: 0.0085
#
# locat:
#     Document D12:: 0.0069
#
# neck:
#     Document D12:: 0.0055
#     Document D13:: 0.0034
#
# produc:
#     Document D12:: 0.0047
#     Document D13:: 0.0029
#     Document D14:: 0.0082
#
# hormon:
#     Document D12:: 0.0036
#     Document D13:: 0.0022
#     Document D14:: 0.0063
#     Document D16:: 0.0022
#     Document D19:: 0.0018
#
# regul:
#     Document D12:: 0.0041
#     Document D13:: 0.0025
#     Document D20:: 0.0009
#     Document D22:: 0.0019
#
# metabol:
#     Document D12:: 0.0055
#     Document D13:: 0.0034
#
# heart:
#     Document D12:: 0.0041
#     Document D13:: 0.0025
#     Document D20:: 0.0009
#     Document D23:: 0.0020
#
# temperatur:
#     Document D12:: 0.0055
#     Document D13:: 0.0034
#
# mood:
#     Document D12:: 0.0041
#     Document D13:: 0.0025
#     Document D27:: 0.0011
#     Document D31:: 0.0020
#
# engin:
#     Document D12:: 0.0047
#     Document D13:: 0.0029
#     Document D14:: 0.0082
#
# unit:
#     Document D12:: 0.0069
#
# influenc:
#     Document D12:: 0.0069
#
# virtual:
#     Document D12:: 0.0069
#
# everi:
#     Document D12:: 0.0069
#
# organ:
#     Document D12:: 0.0069
#
# deeper:
#     Document D12:: 0.0055
#     Document D22:: 0.0026
#
# dive:
#     Document D12:: 0.0047
#     Document D21:: 0.0029
#     Document D23:: 0.0023
#
# fascin:
#     Document D12:: 0.0055
#     Document D31:: 0.0027
#
# function:
#     Document D12:: 0.0029
#     Document D18:: 0.0013
#     Document D19:: 0.0015
#     Document D20:: 0.0007
#     Document D22:: 0.0014
#     Document D27:: 0.0008
#     Document D31:: 0.0014
#
# product:
#     Document D12:: 0.0047
#     Document D16:: 0.0028
#     Document D27:: 0.0013
#
# primarili:
#     Document D12:: 0.0069
#
# thyroxin:
#     Document D12:: 0.0069
#
# main:
#     Document D12:: 0.0055
#     Document D27:: 0.0015
#
# storag:
#     Document D12:: 0.0069
#
# convert:
#     Document D12:: 0.0069
#
# triiodothyronin:
#     Document D12:: 0.0069
#
# american:
#     Document D12:: 0.0029
#     Document D13:: 0.0018
#     Document D14:: 0.0051
#     Document D15:: 0.0053
#     Document D16:: 0.0018
#     Document D20:: 0.0007
#     Document D22:: 0.0014
#
# provid:
#     Document D12:: 0.0036
#     Document D13:: 0.0022
#     Document D14:: 0.0063
#     Document D15:: 0.0066
#     Document D16:: 0.0022
#
# comprehens:
#     Document D12:: 0.0036
#     Document D13:: 0.0022
#     Document D14:: 0.0063
#     Document D15:: 0.0066
#     Document D16:: 0.0022
#
# diagnosi:
#     Document D12:: 0.0026
#     Document D13:: 0.0016
#     Document D14:: 0.0046
#     Document D15:: 0.0048
#     Document D16:: 0.0016
#     Document D27:: 0.0007
#     Document D28:: 0.0015
#     Document D31:: 0.0013
#
# unravel:
#     Document D13:: 0.0043
#
# butterfli:
#     Document D13:: 0.0043
#
# secret:
#     Document D13:: 0.0034
#     Document D23:: 0.0027
#
# nestl:
#     Document D13:: 0.0043
#
# play:
#     Document D13:: 0.0043
#
# role:
#     Document D13:: 0.0043
#
# symphoni:
#     Document D13:: 0.0043
#
# delic:
#     Document D13:: 0.0043
#
# maestro:
#     Document D13:: 0.0043
#
# tune:
#     Document D13:: 0.0043
#
# emerg:
#     Document D13:: 0.0043
#
# health:
#     Document D13:: 0.0013
#     Document D18:: 0.0010
#     Document D19:: 0.0011
#     Document D20:: 0.0005
#     Document D21:: 0.0014
#     Document D23:: 0.0011
#     Document D27:: 0.0006
#     Document D30:: 0.0050
#     Document D31:: 0.0011
#     Document D32:: 0.0067
#
# let:
#     Document D13:: 0.0022
#     Document D21:: 0.0023
#     Document D22:: 0.0017
#     Document D23:: 0.0018
#     Document D24:: 0.0017
#
# delv:
#     Document D13:: 0.0029
#     Document D22:: 0.0022
#     Document D24:: 0.0022
#
# disord:
#     Document D13:: 0.0043
#
# explor:
#     Document D13:: 0.0018
#     Document D21:: 0.0018
#     Document D22:: 0.0014
#     Document D23:: 0.0014
#     Document D24:: 0.0014
#     Document D30:: 0.0066
#     Document D32:: 0.0090
#
# type:
#     Document D13:: 0.0034
#     Document D27:: 0.0015
#
# option:
#     Document D13:: 0.0034
#     Document D16:: 0.0033
#
# addit:
#     Document D13:: 0.0025
#     Document D16:: 0.0025
#     Document D20:: 0.0009
#     Document D24:: 0.0020
#
# hypothyroid:
#     Document D13:: 0.0029
#     Document D16:: 0.0028
#     Document D18:: 0.0021
#
# underperform:
#     Document D13:: 0.0043
#
# insuffici:
#     Document D13:: 0.0043
#
# lead:
#     Document D13:: 0.0034
#     Document D14:: 0.0096
#
# imagin:
#     Document D13:: 0.0043
#
# sluggish:
#     Document D13:: 0.0043
#
# struggl:
#     Document D13:: 0.0043
#
# power:
#     Document D13:: 0.0034
#     Document D32:: 0.0169
#
# way:
#     Document D13:: 0.0043
#
# energi:
#     Document D13:: 0.0025
#     Document D18:: 0.0019
#     Document D19:: 0.0020
#     Document D27:: 0.0011
#
# gain:
#     Document D13:: 0.0043
#
# difficulti:
#     Document D13:: 0.0034
#     Document D15:: 0.0100
#
# lose:
#     Document D13:: 0.0043
#
# weight:
#     Document D13:: 0.0025
#     Document D14:: 0.0071
#     Document D18:: 0.0019
#     Document D21:: 0.0026
#
# cold:
#     Document D13:: 0.0043
#
# skin:
#     Document D13:: 0.0029
#     Document D18:: 0.0021
#     Document D21:: 0.0029
#
# hair:
#     Document D13:: 0.0043
#
# swing:
#     Document D13:: 0.0043
#
# heavi:
#     Document D13:: 0.0043
#
# menstrual:
#     Document D13:: 0.0029
#     Document D20:: 0.0011
#     Document D22:: 0.0022
#
# period:
#     Document D13:: 0.0043
#
# hyperthyroid:
#     Document D14:: 0.0063
#     Document D16:: 0.0022
#     Document D20:: 0.0008
#     Document D23:: 0.0018
#     Document D24:: 0.0017
#
# contrast:
#     Document D14:: 0.0121
#
# overenthusiast:
#     Document D14:: 0.0121
#
# excess:
#     Document D14:: 0.0096
#     Document D16:: 0.0033
#
# think:
#     Document D14:: 0.0121
#
# rev:
#     Document D14:: 0.0121
#
# put:
#     Document D14:: 0.0121
#
# overdr:
#     Document D14:: 0.0121
#
# loss:
#     Document D14:: 0.0082
#     Document D18:: 0.0021
#     Document D21:: 0.0029
#
# nervous:
#     Document D14:: 0.0082
#     Document D20:: 0.0011
#     Document D24:: 0.0022
#
# heartbeat:
#     Document D14:: 0.0121
#
# palpit:
#     Document D14:: 0.0082
#     Document D20:: 0.0011
#     Document D23:: 0.0023
#
# sweat:
#     Document D14:: 0.0121
#
# sleep:
#     Document D14:: 0.0063
#     Document D20:: 0.0008
#     Document D22:: 0.0017
#     Document D23:: 0.0018
#     Document D24:: 0.0017
#
# goiter:
#     Document D15:: 0.0074
#     Document D16:: 0.0025
#     Document D18:: 0.0019
#     Document D21:: 0.0026
#
# visibl:
#     Document D15:: 0.0126
#
# enlarg:
#     Document D15:: 0.0126
#
# reason:
#     Document D15:: 0.0126
#
# iodin:
#     Document D15:: 0.0074
#     Document D16:: 0.0025
#     Document D18:: 0.0019
#     Document D21:: 0.0026
#
# autoimmun:
#     Document D15:: 0.0126
#
# nodul:
#     Document D15:: 0.0100
#     Document D16:: 0.0033
#
# symptomat:
#     Document D15:: 0.0126
#
# sometim:
#     Document D15:: 0.0126
#
# swallow:
#     Document D15:: 0.0126
#
# breath:
#     Document D15:: 0.0126
#
# fortun:
#     Document D16:: 0.0042
#
# treatabl:
#     Document D16:: 0.0042
#
# simpl:
#     Document D16:: 0.0042
#
# measur:
#     Document D16:: 0.0042
#
# shed:
#     Document D16:: 0.0042
#
# light:
#     Document D16:: 0.0042
#
# underli:
#     Document D16:: 0.0042
#
# base:
#     Document D16:: 0.0033
#     Document D25:: 0.0068
#
# avail:
#     Document D16:: 0.0018
#     Document D18:: 0.0013
#     Document D19:: 0.0015
#     Document D20:: 0.0007
#     Document D22:: 0.0014
#     Document D23:: 0.0014
#     Document D24:: 0.0014
#
# synthet:
#     Document D16:: 0.0042
#
# levothyroxin:
#     Document D16:: 0.0042
#
# miss:
#     Document D16:: 0.0042
#
# block:
#     Document D16:: 0.0042
#
# radioact:
#     Document D16:: 0.0042
#
# destroy:
#     Document D16:: 0.0042
#
# overact:
#     Document D16:: 0.0042
#
# tissu:
#     Document D16:: 0.0042
#
# case:
#     Document D16:: 0.0042
#
# surgeri:
#     Document D16:: 0.0042
#
# may:
#     Document D16:: 0.0025
#     Document D18:: 0.0019
#     Document D19:: 0.0020
#     Document D20:: 0.0009
#
# depend:
#     Document D16:: 0.0016
#     Document D18:: 0.0012
#     Document D19:: 0.0013
#     Document D20:: 0.0006
#     Document D22:: 0.0012
#     Document D23:: 0.0013
#     Document D24:: 0.0013
#     Document D31:: 0.0013
#
# supplement:
#     Document D16:: 0.0033
#     Document D27:: 0.0015
#
# recommend:
#     Document D16:: 0.0016
#     Document D18:: 0.0012
#     Document D19:: 0.0013
#     Document D20:: 0.0006
#     Document D22:: 0.0012
#     Document D23:: 0.0013
#     Document D24:: 0.0013
#     Document D31:: 0.0013
#
# aspir:
#     Document D16:: 0.0042
#
# biopsi:
#     Document D16:: 0.0042
#
# determin:
#     Document D16:: 0.0042
#
# benign:
#     Document D16:: 0.0042
#
# cancer:
#     Document D16:: 0.0042
#
# vari:
#     Document D16:: 0.0018
#     Document D18:: 0.0013
#     Document D19:: 0.0015
#     Document D20:: 0.0007
#     Document D22:: 0.0014
#     Document D23:: 0.0014
#     Document D24:: 0.0014
#
# result:
#     Document D16:: 0.0042
#
# monitor:
#     Document D16:: 0.0028
#     Document D18:: 0.0021
#     Document D19:: 0.0023
#
# offer:
#     Document D18:: 0.0017
#     Document D19:: 0.0018
#     Document D27:: 0.0010
#     Document D28:: 0.0021
#     Document D31:: 0.0018
#
# exampl:
#     Document D18:: 0.0032
#
# ashwagandha:
#     Document D18:: 0.0025
#     Document D19:: 0.0027
#
# desir:
#     Document D18:: 0.0025
#     Document D19:: 0.0027
#
# gener:
#     Document D18:: 0.0025
#     Document D19:: 0.0027
#
# mg:
#     Document D18:: 0.0025
# ...
#     Document D22:: 0.0019
#     Document D23:: 0.0020
#
# liquid:
#     Document D18:: 0.0025
#     Document D19:: 0.0027
#
# dissolv:
#     Document D18:: 0.0025
#     Document D19:: 0.0027
#
# alcohol:
#     Document D18:: 0.0025
#     Document D19:: 0.0027
#
# bladderwrack:
#     Document D18:: 0.0025
#     Document D21:: 0.0035
#
# sourc:
#     Document D18:: 0.0019
#     Document D21:: 0.0026
#     Document D31:: 0.0020
#     Document D32:: 0.0125
#
# studi:
#     Document D18:: 0.0032
#
# eleuthero:
#     Document D18:: 0.0032
#
# siberian:
#     Document D18:: 0.0032
#
# ginseng:
#     Document D18:: 0.0025
#     Document D19:: 0.0027
#
# fatigu:
#     Document D18:: 0.0032
#
# improv:
#     Document D18:: 0.0015
#     Document D20:: 0.0007
#     Document D22:: 0.0015
#     Document D27:: 0.0009
#     Document D28:: 0.0019
#     Document D31:: 0.0016
#
# stress:
#     Document D18:: 0.0017
#     Document D20:: 0.0008
#     Document D24:: 0.0017
#     Document D27:: 0.0010
#     Document D28:: 0.0021
#
# histor:
#     Document D18:: 0.0019
#     Document D20:: 0.0009
#     Document D21:: 0.0026
#     Document D23:: 0.0020
#
# natur:
#     Document D18:: 0.0015
#     Document D20:: 0.0007
#     Document D21:: 0.0020
#     Document D23:: 0.0016
#     Document D27:: 0.0009
#     Document D31:: 0.0016
#
# content:
#     Document D18:: 0.0025
#     Document D21:: 0.0035
#
# suppos:
#     Document D18:: 0.0025
#     Document D21:: 0.0035
#
# led:
#     Document D18:: 0.0025
#     Document D21:: 0.0035
#
# remedi:
#     Document D18:: 0.0019
#     Document D21:: 0.0026
#     Document D27:: 0.0011
#     Document D31:: 0.0020
#
# digest:
#     Document D18:: 0.0015
#     Document D20:: 0.0007
#     Document D21:: 0.0020
#     Document D22:: 0.0015
#     Document D23:: 0.0016
#     Document D24:: 0.0016
#
# address:
#     Document D18:: 0.0013
#     Document D20:: 0.0007
#     Document D21:: 0.0018
#     Document D22:: 0.0014
#     Document D23:: 0.0014
#     Document D27:: 0.0008
#     Document D31:: 0.0014
#
# constip:
#     Document D18:: 0.0025
#     Document D21:: 0.0035
#
# complaint:
#     Document D18:: 0.0019
#     Document D20:: 0.0009
#     Document D21:: 0.0026
#     Document D23:: 0.0020
#
# bath:
#     Document D18:: 0.0025
#     Document D21:: 0.0035
#
# sooth:
#     Document D18:: 0.0021
#     Document D21:: 0.0029
#     Document D22:: 0.0022
#
# wound:
#     Document D18:: 0.0017
#     Document D20:: 0.0008
#     Document D21:: 0.0023
#     Document D22:: 0.0017
#     Document D24:: 0.0017
#
# heal:
#     Document D18:: 0.0017
#     Document D20:: 0.0008
#     Document D21:: 0.0023
#     Document D22:: 0.0017
#     Document D24:: 0.0017
#
# astring:
#     Document D18:: 0.0019
#     Document D20:: 0.0009
#     Document D21:: 0.0026
#     Document D22:: 0.0019
#
# thought:
#     Document D18:: 0.0025
#     Document D21:: 0.0035
#
# promot:
#     Document D18:: 0.0010
#     Document D19:: 0.0011
#     Document D20:: 0.0005
#     Document D21:: 0.0014
#     Document D22:: 0.0010
#     Document D23:: 0.0011
#     Document D24:: 0.0010
#     Document D27:: 0.0006
#     Document D28:: 0.0013
#     Document D30:: 0.0050
#
# ancient:
#     Document D19:: 0.0034
#
# modern:
#     Document D19:: 0.0034
#
# indian:
#     Document D19:: 0.0034
#
# winter:
#     Document D19:: 0.0034
#
# cherri:
#     Document D19:: 0.0034
#
# prize:
#     Document D19:: 0.0034
#
# adaptogen:
#     Document D19:: 0.0034
#
# india:
#     Document D19:: 0.0034
#
# part:
#     Document D19:: 0.0034
#
# southeast:
#     Document D19:: 0.0034
#
# ayurved:
#     Document D19:: 0.0034
#
# appear:
#     Document D19:: 0.0016
#     Document D21:: 0.0020
#     Document D22:: 0.0015
#     Document D23:: 0.0016
#     Document D24:: 0.0016
#     Document D26:: 0.0031
#
# oval:
#     Document D19:: 0.0034
#
# yellow:
#     Document D19:: 0.0034
#
# primari:
#     Document D19:: 0.0034
#
# tea:
#     Document D19:: 0.0018
#     Document D20:: 0.0008
#     Document D22:: 0.0017
#     Document D23:: 0.0018
#     Document D24:: 0.0017
#
# relief:
#     Document D19:: 0.0034
#
# anxieti:
#     Document D19:: 0.0015
#     Document D20:: 0.0007
#     Document D22:: 0.0014
#     Document D23:: 0.0014
#     Document D24:: 0.0014
#     Document D27:: 0.0008
#     Document D28:: 0.0017
#
# reduct:
#     Document D19:: 0.0023
#     Document D27:: 0.0013
#     Document D28:: 0.0027
#
# stamina:
#     Document D19:: 0.0034
#
# cognit:
#     Document D19:: 0.0027
#     Document D31:: 0.0027
#
# memori:
#     Document D19:: 0.0034
#
# fertil:
#     Document D19:: 0.0034
#
# pain:
#     Document D19:: 0.0016
#     Document D20:: 0.0007
#     Document D22:: 0.0015
#     Document D27:: 0.0009
#     Document D28:: 0.0019
#     Document D31:: 0.0016
#
# buglewe:
#     Document D20:: 0.0013
#     Document D22:: 0.0026
#
# tribe:
#     Document D20:: 0.0013
#     Document D22:: 0.0026
#
# purpos:
#     Document D20:: 0.0009
#     Document D22:: 0.0019
#     Document D23:: 0.0020
#     Document D24:: 0.0020
#
# valu:
#     Document D20:: 0.0009
#     Document D22:: 0.0019
#     Document D23:: 0.0020
#     Document D24:: 0.0020
#
# arthriti:
#     Document D20:: 0.0013
#     Document D22:: 0.0026
#
# headach:
#     Document D20:: 0.0013
#     Document D22:: 0.0026
#
# cramp:
#     Document D20:: 0.0011
#     Document D22:: 0.0022
#     Document D24:: 0.0022
#
# stomach:
#     Document D20:: 0.0011
#     Document D22:: 0.0022
#     Document D26:: 0.0045
#
# upset:
#     Document D20:: 0.0013
#     Document D22:: 0.0026
#
# diarrhea:
#     Document D20:: 0.0013
#     Document D22:: 0.0026
#
# calm:
#     Document D20:: 0.0009
#     Document D22:: 0.0019
#     Document D23:: 0.0020
#     Document D24:: 0.0020
#
# menstruat:
#     Document D20:: 0.0013
#     Document D22:: 0.0026
#
# cycl:
#     Document D20:: 0.0013
#     Document D22:: 0.0026
#
# eas:
#     Document D20:: 0.0013
#     Document D22:: 0.0026
#
# menopaus:
#     Document D20:: 0.0013
#     Document D22:: 0.0026
#
# dri:
#     Document D20:: 0.0008
#     Document D22:: 0.0017
#     Document D23:: 0.0018
#     Document D24:: 0.0017
#     Document D26:: 0.0035
#
# hawthorn:
#     Document D20:: 0.0013
#     Document D23:: 0.0027
#
# mild:
#     Document D20:: 0.0013
#     Document D23:: 0.0027
#
# doctor:
#     Document D20:: 0.0007
#     Document D23:: 0.0014
#     Document D27:: 0.0008
#     Document D28:: 0.0017
#     Document D30:: 0.0066
#     Document D31:: 0.0014
#     Document D32:: 0.0090
#
# lie:
#     Document D20:: 0.0013
#     Document D23:: 0.0027
#
# cardiovascular:
#     Document D20:: 0.0013
#     Document D23:: 0.0027
#
# pressur:
#     Document D20:: 0.0013
#     Document D23:: 0.0027
#
# lower:
#     Document D20:: 0.0013
#     Document D23:: 0.0027
#
# disturb:
#     Document D20:: 0.0013
#     Document D23:: 0.0027
#
# urinari:
#     Document D20:: 0.0013
#     Document D23:: 0.0027
#
# lemon:
#     Document D20:: 0.0013
#     Document D24:: 0.0026
#
# balm:
#     Document D20:: 0.0013
#     Document D24:: 0.0026
#
# relax:
#     Document D20:: 0.0009
#     Document D24:: 0.0020
#     Document D27:: 0.0011
#     Document D28:: 0.0024
#
# insomnia:
#     Document D20:: 0.0013
#     Document D24:: 0.0026
#
# rest:
#     Document D20:: 0.0013
#     Document D24:: 0.0026
#
# allevi:
#     Document D20:: 0.0013
#     Document D24:: 0.0026
#
# bloat:
#     Document D20:: 0.0013
#     Document D24:: 0.0026
#
# nausea:
#     Document D20:: 0.0013
#     Document D24:: 0.0026
#
# beverag:
#     Document D20:: 0.0011
#     Document D24:: 0.0022
#     Document D26:: 0.0045
#
# refresh:
#     Document D20:: 0.0013
#     Document D24:: 0.0026
#
# flavor:
#     Document D20:: 0.0013
#     Document D24:: 0.0026
#
# made:
#     Document D20:: 0.0013
#     Document D24:: 0.0026
#
# popular:
#     Document D20:: 0.0013
#     Document D24:: 0.0026
#
# soup:
#     Document D20:: 0.0013
#     Document D24:: 0.0026
#
# salad:
#     Document D20:: 0.0013
#     Document D24:: 0.0026
#
# sauc:
#     Document D20:: 0.0013
#     Document D24:: 0.0026
#
# oil:
#     Document D20:: 0.0013
#     Document D24:: 0.0026
#
# seawe:
#     Document D21:: 0.0044
#
# surpris:
#     Document D21:: 0.0044
#
# fucu:
#     Document D21:: 0.0044
#
# vesiculosu:
#     Document D21:: 0.0044
#
# brown:
#     Document D21:: 0.0044
#
# found:
#     Document D21:: 0.0035
#     Document D26:: 0.0053
#
# northern:
#     Document D21:: 0.0044
#
# atlant:
#     Document D21:: 0.0044
#
# pacif:
#     Document D21:: 0.0044
#
# ocean:
#     Document D21:: 0.0044
#
# particularli:
#     Document D21:: 0.0044
#
# coastal:
#     Document D21:: 0.0044
#
# europ:
#     Document D21:: 0.0029
#     Document D23:: 0.0023
#     Document D24:: 0.0022
#
# uniqu:
#     Document D21:: 0.0044
#
# featur:
#     Document D21:: 0.0026
#     Document D22:: 0.0019
#     Document D23:: 0.0020
#     Document D24:: 0.0020
#
# leatheri:
#     Document D21:: 0.0044
#
# frond:
#     Document D21:: 0.0044
#
# air:
#     Document D21:: 0.0044
#
# bladder:
#     Document D21:: 0.0044
#
# henc:
#     Document D21:: 0.0044
#
# name:
#     Document D21:: 0.0029
#     Document D25:: 0.0058
#     Document D26:: 0.0045
#
# rocki:
#     Document D21:: 0.0044
#
# shore:
#     Document D21:: 0.0044
#
# intertid:
#     Document D21:: 0.0044
#
# zone:
#     Document D21:: 0.0044
#
# dens:
#     Document D21:: 0.0044
#
# underwat:
#     Document D21:: 0.0044
#
# forest:
#     Document D21:: 0.0044
#
# versatil:
#     Document D22:: 0.0026
#     Document D24:: 0.0026
#
# lycopu:
#     Document D22:: 0.0033
#
# americanu:
#     Document D22:: 0.0033
#
# virginianu:
#     Document D22:: 0.0033
#
# north:
#     Document D22:: 0.0033
#
# long:
#     Document D22:: 0.0033
#
# histori:
#     Document D22:: 0.0033
#
# member:
#     Document D22:: 0.0022
#     Document D24:: 0.0022
#     Document D26:: 0.0045
#
# mint:
#     Document D22:: 0.0026
#     Document D24:: 0.0026
#
# boast:
#     Document D22:: 0.0026
#     Document D24:: 0.0026
#
# squar:
#     Document D22:: 0.0033
#
# wrinkl:
#     Document D22:: 0.0026
#     Document D24:: 0.0026
#
# blue:
#     Document D22:: 0.0033
#
# violet:
#     Document D22:: 0.0033
#
# thrive:
#     Document D22:: 0.0022
#     Document D23:: 0.0023
#     Document D24:: 0.0022
#
# moist:
#     Document D22:: 0.0033
#
# meadow:
#     Document D22:: 0.0033
#
# streamsid:
#     Document D22:: 0.0033
#
# shadi:
#     Document D22:: 0.0033
#
# woodland:
#     Document D22:: 0.0022
#     Document D23:: 0.0023
#     Document D26:: 0.0045
#
# thorni:
#     Document D23:: 0.0034
#
# distinct:
#     Document D23:: 0.0027
#     Document D24:: 0.0026
#
# red:
#     Document D23:: 0.0034
#
# berri:
#     Document D23:: 0.0034
#
# branch:
#     Document D23:: 0.0034
#
# mainstay:
#     Document D23:: 0.0034
#
# rever:
#     Document D23:: 0.0034
#
# find:
#     Document D23:: 0.0034
#
# within:
#     Document D23:: 0.0027
#     Document D27:: 0.0015
#
# prickli:
#     Document D23:: 0.0034
#
# spini:
#     Document D23:: 0.0034
#
# lobe:
#     Document D23:: 0.0034
#
# cluster:
#     Document D23:: 0.0027
#     Document D25:: 0.0068
#
# white:
#     Document D23:: 0.0027
#     Document D24:: 0.0026
#
# bright:
#     Document D23:: 0.0034
#
# hedgerow:
#     Document D23:: 0.0034
#
# sunni:
#     Document D23:: 0.0027
#     Document D24:: 0.0026
#
# field:
#     Document D23:: 0.0034
#
# lemoni:
#     Document D24:: 0.0033
#
# delight:
#     Document D24:: 0.0033
#
# aroma:
#     Document D24:: 0.0033
#
# culinari:
#     Document D24:: 0.0033
#
# fragrant:
#     Document D24:: 0.0033
#
# scent:
#     Document D24:: 0.0033
#
# garden:
#     Document D24:: 0.0033
#
# readili:
#     Document D24:: 0.0033
#
# creat:
#     Document D24:: 0.0033
#
# verdant:
#     Document D24:: 0.0033
#
# patch:
#     Document D24:: 0.0033
#
# african:
#     Document D25:: 0.0086
#
# teak:
#     Document D25:: 0.0086
#
# iroko:
#     Document D25:: 0.0086
#
# mvule:
#     Document D25:: 0.0086
#
# odum:
#     Document D25:: 0.0086
#
# tule:
#     Document D25:: 0.0086
#
# counterwood:
#     Document D25:: 0.0086
#
# larg:
#     Document D25:: 0.0086
#
# decidu:
#     Document D25:: 0.0068
#     Document D26:: 0.0053
#
# tropic:
#     Document D25:: 0.0086
#
# tall:
#     Document D25:: 0.0086
#
# straight:
#     Document D25:: 0.0086
#
# trunk:
#     Document D25:: 0.0086
#
# smooth:
#     Document D25:: 0.0086
#
# bark:
#     Document D25:: 0.0086
#
# glossi:
#     Document D25:: 0.0086
#
# round:
#     Document D25:: 0.0086
#
# point:
#     Document D25:: 0.0051
#     Document D27:: 0.0011
#     Document D28:: 0.0024
#     Document D31:: 0.0020
#
# tip:
#     Document D25:: 0.0086
#
# fruit:
#     Document D25:: 0.0068
#     Document D26:: 0.0053
#
# drupe:
#     Document D25:: 0.0086
#
# walnut:
#     Document D25:: 0.0086
#
# contain:
#     Document D25:: 0.0086
#
# seed:
#     Document D25:: 0.0086
#
# tsp:
#     Document D25:: 0.0086
#
# knobwood:
#     Document D26:: 0.0066
#
# rutacea:
#     Document D26:: 0.0066
#
# close:
#     Document D26:: 0.0066
#
# relat:
#     Document D26:: 0.0066
#
# citru:
#     Document D26:: 0.0066
#
# aromat:
#     Document D26:: 0.0066
#
# ethiopia:
#     Document D26:: 0.0066
#
# southward:
#     Document D26:: 0.0066
#
# mozambiqu:
#     Document D26:: 0.0066
#
# grassland:
#     Document D26:: 0.0066
#
# termit:
#     Document D26:: 0.0066
#
# mound:
#     Document D26:: 0.0066
#
# shoot:
#     Document D26:: 0.0066
#
# decoct:
#     Document D26:: 0.0066
#
# ailment:
#     Document D26:: 0.0066
#
# problem:
#     Document D26:: 0.0066
#
# fever:
#     Document D26:: 0.0066
#
# toothach:
#     Document D26:: 0.0066
#
# eat:
#     Document D26:: 0.0066
#
# leaf:
#     Document D26:: 0.0066
#
# navig:
#     Document D27:: 0.0019
#
# complementari:
#     Document D27:: 0.0013
#     Document D28:: 0.0027
#     Document D31:: 0.0023
#
# approach:
#     Document D27:: 0.0013
#     Document D28:: 0.0027
#     Document D31:: 0.0023
#
# cam:
#     Document D27:: 0.0019
#
# encompass:
#     Document D27:: 0.0019
#
# outsid:
#     Document D27:: 0.0019
#
# acupunctur:
#     Document D27:: 0.0019
#
# medit:
#     Document D27:: 0.0015
#     Document D28:: 0.0032
#
# yoga:
#     Document D27:: 0.0015
#     Document D28:: 0.0032
#
# vast:
#     Document D27:: 0.0015
#     Document D31:: 0.0027
#
# valuabl:
#     Document D27:: 0.0013
#     Document D30:: 0.0106
#     Document D31:: 0.0023
#
# landscap:
#     Document D27:: 0.0019
#
# caution:
#     Document D27:: 0.0019
#
# awar:
#     Document D27:: 0.0015
#     Document D31:: 0.0027
#
# categor:
#     Document D27:: 0.0019
#
# group:
#     Document D27:: 0.0019
#
# tai:
#     Document D27:: 0.0019
#
# chi:
#     Document D27:: 0.0019
#
# biofeedback:
#     Document D27:: 0.0019
#
# connect:
#     Document D27:: 0.0019
#
# mind:
#     Document D27:: 0.0019
#
# manipul:
#     Document D27:: 0.0019
#
# chiropract:
#     Document D27:: 0.0019
#
# massag:
#     Document D27:: 0.0019
#
# osteopathi:
#     Document D27:: 0.0019
#
# focu:
#     Document D27:: 0.0019
#
# muscl:
#     Document D27:: 0.0019
#
# bone:
#     Document D27:: 0.0019
#
# joint:
#     Document D27:: 0.0019
#
# physic:
#     Document D27:: 0.0019
#
# vitamin:
#     Document D27:: 0.0019
#
# dietari:
#     Document D27:: 0.0019
#
# substanc:
#     Document D27:: 0.0019
#
# reiki:
#     Document D27:: 0.0019
#
# magnet:
#     Document D27:: 0.0019
#
# involv:
#     Document D27:: 0.0019
#
# concern:
#     Document D27:: 0.0015
#     Document D31:: 0.0027
#
# chronic:
#     Document D27:: 0.0015
#     Document D28:: 0.0032
#
# depress:
#     Document D27:: 0.0015
#     Document D28:: 0.0032
#
# mental:
#     Document D27:: 0.0015
#     Document D28:: 0.0032
#
# emot:
#     Document D27:: 0.0015
#     Document D28:: 0.0032
#
# enhanc:
#     Document D27:: 0.0013
#     Document D28:: 0.0027
#     Document D30:: 0.0106
#
# outcom:
#     Document D27:: 0.0015
#     Document D28:: 0.0032
#
# never:
#     Document D27:: 0.0013
#     Document D28:: 0.0027
#     Document D31:: 0.0023
#
# risk:
#     Document D27:: 0.0013
#     Document D28:: 0.0027
#     Document D31:: 0.0023
#
# carri:
#     Document D27:: 0.0015
#     Document D28:: 0.0032
#
# back:
#     Document D27:: 0.0013
#     Document D28:: 0.0027
#     Document D31:: 0.0023
#
# other:
#     Document D27:: 0.0013
#     Document D28:: 0.0027
#     Document D31:: 0.0023
#
# strong:
#     Document D27:: 0.0013
#     Document D28:: 0.0027
#     Document D31:: 0.0023
#
# choos:
#     Document D27:: 0.0011
#     Document D28:: 0.0024
#     Document D31:: 0.0020
#     Document D32:: 0.0125
#
# reput:
#     Document D27:: 0.0011
#     Document D28:: 0.0024
#     Document D31:: 0.0020
#     Document D32:: 0.0125
#
# qualif:
#     Document D27:: 0.0013
#     Document D28:: 0.0027
#     Document D31:: 0.0023
#
# seek:
#     Document D27:: 0.0013
#     Document D28:: 0.0027
#     Document D31:: 0.0023
#
# licens:
#     Document D27:: 0.0015
#     Document D28:: 0.0032
#
# conjunct:
#     Document D30:: 0.0157
#
# educ:
#     Document D30:: 0.0157
#
# choic:
#     Document D30:: 0.0157
#
# priorit:
#     Document D30:: 0.0124
#     Document D31:: 0.0027
#
# collabor:
#     Document D30:: 0.0157
#
# journey:
#     Document D30:: 0.0124
#     Document D32:: 0.0169
#
# wealth:
#     Document D31:: 0.0034
#
# breakdown:
#     Document D31:: 0.0034
#
# prefer:
#     Document D31:: 0.0034
#
# align:
#     Document D31:: 0.0034
#
# holist:
#     Document D31:: 0.0034
#
# applic:
#     Document D31:: 0.0034
#
# especi:
#     Document D31:: 0.0034
#
# side:
#     Document D31:: 0.0034
#
# conclus:
#     Document D31:: 0.0034
#
# expertis:
#     Document D31:: 0.0034
#
# paramount:
#     Document D32:: 0.0213
#
# enjoy:
#     Document D32:: 0.0213
